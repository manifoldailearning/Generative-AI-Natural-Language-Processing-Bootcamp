# %%
import requests
import json

# %%
url = 'https://api.nytimes.com/svc/news/v3/content/all/{category}.json'.format(category="technology")
params = {'api-key': "bbDDOxwmJjMwn6K9bWsFsBTMcpP8QAl6", 'limit': 5}
response = requests.get(url,params).text
json_data = json.loads(response)["results"]

# %%
json_data
# Out:
# [{'slug_name': '29roose',
#   'section': 'Technology',
#   'subsection': '',
#   'title': 'The 2022 Good Tech Awards',
#   'abstract': 'Nuclear fusion, generative A.I., bee tracking and more. There’s a lot to like.',
#   'uri': 'nyt://article/acf3bc9f-c065-5658-9448-6514e7c8d1eb',
#   'url': 'https://www.nytimes.com/2022/12/29/technology/good-tech-awards-2022.html',
#   'byline': 'BY KEVIN ROOSE',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2022/12/28/business/00roose-eoy/00roose-eoy-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'New York Times',
#   'updated_date': '2022-12-29T05:00:19-05:00',
#   'created_date': '2022-12-29T05:00:19-05:00',
#   'published_date': '2022-12-29T05:00:19-05:00',
#   'first_published_date': '2022-12-29T05:00:19-05:00',
#   'material_type_facet': 'News',
#   'kicker': 'The Shift',
#   'subheadline': '',
#   'des_facet': ['Venture Capital',
#    'Computers and the Internet',
#    'Artificial Intelligence',
#    'Start-ups',
#    'Social Media',
#    'Bees'],
#   'org_facet': ['Commonwealth Fusion Systems LLC',
#    'Ethereum Foundation',
#    'Lawrence Livermore National Laboratory'],
#   'per_facet': None,
#   'geo_facet': None,
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2022/12/28/business/00roose-eoy/00roose-eoy-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Yadi Liu'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/business/00roose-eoy/00roose-eoy-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Yadi Liu'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/business/00roose-eoy/00roose-eoy-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Yadi Liu'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/business/00roose-eoy/00roose-eoy-articleInline.jpg',
#     'format': 'Normal',
#     'height': 133,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Yadi Liu'}]},
#  {'slug_name': '29techfix',
#   'section': 'Technology',
#   'subsection': 'Personal Tech',
#   'title': 'The Tech That Will Invade Our Lives in 2023',
#   'abstract': 'Say hello to new-and-improved A.I. assistants, and move over to brands like Twitter and Tesla.',
#   'uri': 'nyt://article/36af721c-3604-53d1-9085-32bbe81ccbb2',
#   'url': 'https://www.nytimes.com/2022/12/29/technology/personaltech/new-tech-2023-ai-chat-vr.html',
#   'byline': 'BY BRIAN X. CHEN',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2022/12/28/business/28techfix/28techfix-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'New York Times',
#   'updated_date': '2022-12-29T03:00:10-05:00',
#   'created_date': '2022-12-29T03:00:10-05:00',
#   'published_date': '2022-12-29T03:00:10-05:00',
#   'first_published_date': '2022-12-29T03:00:10-05:00',
#   'material_type_facet': 'News',
#   'kicker': 'Tech Fix',
#   'subheadline': '',
#   'des_facet': ['Computers and the Internet',
#    'Social Media',
#    'Electric and Hybrid Vehicles',
#    'Artificial Intelligence'],
#   'org_facet': ['OpenAI Labs'],
#   'per_facet': None,
#   'geo_facet': None,
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2022/12/28/business/28techfix/28techfix-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Derek Abella'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/business/28techfix/28techfix-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Derek Abella'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/business/28techfix/28techfix-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Derek Abella'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/business/28techfix/28techfix-articleInline.jpg',
#     'format': 'Normal',
#     'height': 133,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Derek Abella'}]},
#  {'slug_name': '28twitter-down',
#   'section': 'Technology',
#   'subsection': '',
#   'title': 'Twitter Users Report Widespread Service Interruptions',
#   'abstract': 'The issues surfaced several days after Elon Musk said he had shut down one of the company’s major data centers.',
#   'uri': 'nyt://article/e9a43e57-77c2-586f-9c25-50ea9c0c758d',
#   'url': 'https://www.nytimes.com/2022/12/28/technology/twitter-outages.html',
#   'byline': 'BY KATE CONGER',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2022/12/28/multimedia/28twitter-down-1-3372/28twitter-down-1-3372-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'New York Times',
#   'updated_date': '2022-12-28T21:08:25-05:00',
#   'created_date': '2022-12-28T21:08:25-05:00',
#   'published_date': '2022-12-28T21:08:25-05:00',
#   'first_published_date': '2022-12-28T21:08:25-05:00',
#   'material_type_facet': 'News',
#   'kicker': '',
#   'subheadline': '',
#   'des_facet': ['Computers and the Internet',
#    'Computer Network Outages',
#    'Social Media',
#    'Desktop Computers'],
#   'org_facet': ['Twitter'],
#   'per_facet': None,
#   'geo_facet': None,
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2022/12/28/multimedia/28twitter-down-1-3372/28twitter-down-1-3372-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The cause of widely reported Twitter outages on Wednesday was not immediately clear.',
#     'copyright': 'Carlos Barria/Reuters'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/multimedia/28twitter-down-1-3372/28twitter-down-1-3372-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The cause of widely reported Twitter outages on Wednesday was not immediately clear.',
#     'copyright': 'Carlos Barria/Reuters'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/multimedia/28twitter-down-1-3372/28twitter-down-1-3372-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The cause of widely reported Twitter outages on Wednesday was not immediately clear.',
#     'copyright': 'Carlos Barria/Reuters'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/multimedia/28twitter-down-1-3372/28twitter-down-1-3372-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The cause of widely reported Twitter outages on Wednesday was not immediately clear.',
#     'copyright': 'Carlos Barria/Reuters'}]},
#  {'slug_name': '28covid-misinfo',
#   'section': 'Technology',
#   'subsection': '',
#   'title': 'As Covid-19 Continues to Spread, So Does Misinformation About It',
#   'abstract': 'Doctors are exasperated by the persistence of false and misleading claims about the virus.',
#   'uri': 'nyt://article/2f6ec271-e8d2-5d51-bc81-d525573a88f2',
#   'url': 'https://www.nytimes.com/2022/12/28/technology/covid-misinformation-online.html',
#   'byline': 'BY TIFFANY HSU',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2022/12/23/business/00covid-misinfo-01/00covid-misinfo-01-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'New York Times',
#   'updated_date': '2022-12-28T05:00:22-05:00',
#   'created_date': '2022-12-28T05:00:22-05:00',
#   'published_date': '2022-12-28T05:00:22-05:00',
#   'first_published_date': '2022-12-28T05:00:22-05:00',
#   'material_type_facet': 'News',
#   'kicker': '',
#   'subheadline': '',
#   'des_facet': ['Coronavirus (2019-nCoV)',
#    'Rumors and Misinformation',
#    'Social Media',
#    'Vaccination and Immunization',
#    'Computers and the Internet',
#    'Freedom of Speech and Expression'],
#   'org_facet': ['Centers for Disease Control and Prevention',
#    'Facebook Inc',
#    'Google Inc',
#    'Twitter'],
#   'per_facet': ['Fauci, Anthony S', 'Musk, Elon'],
#   'geo_facet': None,
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2022/12/23/business/00covid-misinfo-01/00covid-misinfo-01-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The constant barrage of bad information about Covid-19 has made it increasingly difficult for accurate advice to break through, misinformation researchers say.',
#     'copyright': 'Boston Globe, via Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2022/12/23/business/00covid-misinfo-01/00covid-misinfo-01-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The constant barrage of bad information about Covid-19 has made it increasingly difficult for accurate advice to break through, misinformation researchers say.',
#     'copyright': 'Boston Globe, via Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2022/12/23/business/00covid-misinfo-01/00covid-misinfo-01-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The constant barrage of bad information about Covid-19 has made it increasingly difficult for accurate advice to break through, misinformation researchers say.',
#     'copyright': 'Boston Globe, via Getty Images'},
#    {'url': 'https://static01.nyt.com/images/2022/12/23/business/00covid-misinfo-01/00covid-misinfo-01-articleInline.jpg',
#     'format': 'Normal',
#     'height': 127,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': 'The constant barrage of bad information about Covid-19 has made it increasingly difficult for accurate advice to break through, misinformation researchers say.',
#     'copyright': 'Boston Globe, via Getty Images'}]},
#  {'slug_name': '28google-anxiety',
#   'section': 'Technology',
#   'subsection': '',
#   'title': 'Google Employees Brace for a Cost-Cutting Drive as Anxiety Mounts',
#   'abstract': 'The tech giant has so far taken steps to streamline without mass layoffs, but employees are girding for deeper cuts.',
#   'uri': 'nyt://article/db8a0592-6c7b-51b5-b880-1919254aec95',
#   'url': 'https://www.nytimes.com/2022/12/28/technology/google-job-cuts.html',
#   'byline': 'BY NICO GRANT',
#   'thumbnail_standard': 'https://static01.nyt.com/images/2022/12/28/business/28google-anxiety/28google-anxiety-thumbStandard.jpg',
#   'item_type': 'Article',
#   'source': 'New York Times',
#   'updated_date': '2022-12-28T05:00:14-05:00',
#   'created_date': '2022-12-28T05:00:14-05:00',
#   'published_date': '2022-12-28T05:00:14-05:00',
#   'first_published_date': '2022-12-28T05:00:14-05:00',
#   'material_type_facet': 'News',
#   'kicker': '',
#   'subheadline': '',
#   'des_facet': ['Layoffs and Job Reductions',
#    'Economic Conditions and Trends',
#    'United States Economy',
#    'Online Advertising',
#    'Workplace Environment'],
#   'org_facet': ['Google Inc', 'Alphabet Inc'],
#   'per_facet': ['Pichai, Sundar'],
#   'geo_facet': None,
#   'related_urls': None,
#   'multimedia': [{'url': 'https://static01.nyt.com/images/2022/12/28/business/28google-anxiety/28google-anxiety-thumbStandard.jpg',
#     'format': 'Standard Thumbnail',
#     'height': 75,
#     'width': 75,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Jon Krause'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/business/28google-anxiety/28google-anxiety-mediumThreeByTwo210.jpg',
#     'format': 'mediumThreeByTwo210',
#     'height': 140,
#     'width': 210,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Jon Krause'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/business/28google-anxiety/28google-anxiety-mediumThreeByTwo440.jpg',
#     'format': 'mediumThreeByTwo440',
#     'height': 293,
#     'width': 440,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Jon Krause'},
#    {'url': 'https://static01.nyt.com/images/2022/12/28/business/28google-anxiety/28google-anxiety-articleInline.jpg',
#     'format': 'Normal',
#     'height': 133,
#     'width': 190,
#     'type': 'image',
#     'subtype': 'photo',
#     'caption': '',
#     'copyright': 'Jon Krause'}]}]
