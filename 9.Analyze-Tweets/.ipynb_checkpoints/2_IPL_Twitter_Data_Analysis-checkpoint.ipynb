# %% [markdown]
# # Fetching Tweets using Tweepy

# %% [markdown]
# ### Import Libraries

# %%
# !pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 KB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from vaderSentiment) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->vaderSentiment) (2022.12.7)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import tweepy
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
stop = stopwords.words('english')
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import nltk
import re
import matplotlib.pyplot as plt
from matplotlib.cm import Reds, Greens, Purples, Greys
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import time

# %%
ACCESS_TOKEN = '1414851728189497352-bT9Nsa46Th3AGXG9X0WSiK6AMNH7iV'
ACCESS_SECRET = 'uZaHUSeyNG6ogJvF31aI3GRzZ0xh4d0dboNCq5Ea60vqz'
CONSUMER_KEY = 'nito5Rtvyl7XVWPtkyhy8RIBj'
CONSUMER_SECRET = 'nvXpfefyzZMmx1cQmyo7AfH7AUEsq8hnzphvY4kqxond93L9P6'

import tweepy

def connect_to_twiiter_OAuth():
  auth = tweepy.OAuthHandler(CONSUMER_KEY,CONSUMER_SECRET)
  auth.set_access_token(ACCESS_TOKEN,ACCESS_SECRET)

  api = tweepy.API(auth)
  return api


api = connect_to_twiiter_OAuth()



# Setup access to API
def connect_to_twitter_OAuth():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    api = tweepy.API(auth)
    return api


# Create API object
api = connect_to_twitter_OAuth()

# %%
# Define the tweet text
tweet='this is an automated test tweet using tweepy from NLP course tet'

# Generate text tweet
api.update_status(tweet)

# %% [markdown]
# #### Getting Tweets from different ipl currencies

# %%
ipl_list={'@RCBTweets','@mipaltan','@ChennaiIPL', '@GujTitansIPL', '@PunjabKingsIPL', '@LucknowIPL', '@Thisisnewdelhi'}

# %%
# Array to hold tweet data
tweet_list = []
# Iterate through all the ipl_list
for ipl in ipl_list:
    # Bring out the 300 tweets
    ipl_tweets = api.user_timeline(ipl, count=300)
    time.sleep(1)
    # Loop through the 300 tweets
    for tweet in ipl_tweets:
        tweet_id = tweet.id # unique integer identifier for tweet
        text = tweet.text # utf-8 text of tweet
        favorite_count = tweet.favorite_count
        retweet_count = tweet.retweet_count
        created_at = tweet.created_at # utc time tweet created
        source = tweet.source # utility used to post tweet
        reply_to_status = tweet.in_reply_to_status_id # if reply int of orginal tweet id
        reply_to_user = tweet.in_reply_to_screen_name # if reply original tweetes screenname
        retweets = tweet.retweet_count # number of times this tweet retweeted
        favorites = tweet.favorite_count # number of time this tweet liked
        # append attributes to list
        tweet_list.append({'ipl':ipl,
                          'tweet_id':tweet_id, 
                          'text':text, 
                          'favorite_count':favorite_count,
                          'retweet_count':retweet_count,
                          'created_at':created_at, 
                          'source':source, 
                          'reply_to_status':reply_to_status, 
                          'reply_to_user':reply_to_user,
                          'retweets':retweets,
                          'favorites':favorites})

# %%
tweet_data=pd.DataFrame(tweet_list)

# %%
tweet_data.head()
# Out:
#          ipl             tweet_id  \
# 0  @mipaltan  1621488336761393155
# 1  @mipaltan  1621484633249714177
# 2  @mipaltan  1621460732905951232
# 3  @mipaltan  1621393043185348608
# 4  @mipaltan  1621389268487901186
#
#                                                 text  favorite_count  \
# 0  The 𝚑𝚎𝚛𝚘 from the final over of 2007 T20 World...             511
# 1  The moment that'll forever be etched in our he...             515
# 2  ©️aptain RO en route Nagpur for #BGT ✈️\n\n#On...            2447
# 3  🗣️ Our Head Coach @markb46 on the 🇿🇦 stars who...             442
# 4  💪 Tim bhau at it, this time with his bowling 👌...            1013
#
#    retweet_count          created_at           source  reply_to_status  \
# 0             29 2023-02-03 12:38:39  Twitter Web App              NaN
# 1             30 2023-02-03 12:23:56  Twitter Web App              NaN
# 2            137 2023-02-03 10:48:58  Twitter Web App              NaN
# 3             21 2023-02-03 06:20:00  Twitter Web App              NaN
# 4             38 2023-02-03 06:05:00  Twitter Web App              NaN
#
#   reply_to_user  retweets  favorites
# 0          None        29        511
# 1          None        30        515
# 2          None       137       2447
# 3          None        21        442
# 4          None        38       1013

# %%
tweet_data.shape
# Out:
# (1300, 11)

# %%
tweet_data.to_csv('Tweets.csv',index=None)

# %% [markdown]
# ## Exploring the Data

# %%
data=tweet_data.copy()

# %%
source=data.source.value_counts()

# %%
trace=go.Pie(labels=source.index,values=source,showlegend=False,hole=0.33,text=[str(round(i*100,3))+'%' for i in source/sum(source)],hovertext='Source',
            hoverinfo='label+text',textinfo='text+label'
            )
layout=go.Layout(title="Which Device People are using?")
fig=go.Figure(data=[trace],layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="801c8ad1-fbb5-46c2-a6dd-f4a266c87baf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("801c8ad1-fbb5-46c2-a6dd-f4a266c87baf")) {                    Plotly.newPlot(                        "801c8ad1-fbb5-46c2-a6dd-f4a266c87baf",                        [{"hole":0.33,"hoverinfo":"label+text","hovertext":"Source","labels":["Twitter Web App","Twitter for iPhone","Twitter for Android","Twitter Media Studio","Twitter Web Client","Buffer","Twitter for Advertisers"],"showlegend":false,"text":["49.692%","18.462%","18.0%","5.692%","5.231%","2.462%","0.462%"],"textinfo":"text+label","values":[646,240,234,74,68,32,6],"type":"pie"}],                        {"title":{"text":"Which Device People are using?"},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"ou ...

# %% [markdown]
# ##### Observation:
# - People prefer TweetDeck or Web App.

# %% [markdown]
# #### Most Retweets and Favorites

# %%
source=data.groupby('ipl').agg(sum)[['retweet_count','favorite_count']]

# %%
fig=go.Figure()
fig.add_bar(x=source.index,y=source.retweet_count,name='Retweet Count')
fig.add_bar(x=source.index,y=source.favorite_count,name='Favorite Count')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4455604a-6a33-44a4-9a39-0be62dd0fa3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4455604a-6a33-44a4-9a39-0be62dd0fa3b")) {                    Plotly.newPlot(                        "4455604a-6a33-44a4-9a39-0be62dd0fa3b",                        [{"name":"Retweet Count","x":["@ChennaiIPL","@GujTitansIPL","@LucknowIPL","@PunjabKingsIPL","@RCBTweets","@Thisisnewdelhi","@mipaltan"],"y":[48344.0,17239.0,16032.0,4484.0,41876.0,6268.0,10719.0],"type":"bar"},{"name":"Favorite Count","x":["@ChennaiIPL","@GujTitansIPL","@LucknowIPL","@PunjabKingsIPL","@RCBTweets","@Thisisnewdelhi","@mipaltan"],"y":[747262.0,1625.0,149381.0,89344.0,809957.0,82.0,209774.0],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outli ...

# %%
data.head()
# Out:
#          ipl             tweet_id  \
# 0  @mipaltan  1621488336761393155
# 1  @mipaltan  1621484633249714177
# 2  @mipaltan  1621460732905951232
# 3  @mipaltan  1621393043185348608
# 4  @mipaltan  1621389268487901186
#
#                                                 text  favorite_count  \
# 0  The 𝚑𝚎𝚛𝚘 from the final over of 2007 T20 World...             511
# 1  The moment that'll forever be etched in our he...             515
# 2  ©️aptain RO en route Nagpur for #BGT ✈️\n\n#On...            2447
# 3  🗣️ Our Head Coach @markb46 on the 🇿🇦 stars who...             442
# 4  💪 Tim bhau at it, this time with his bowling 👌...            1013
#
#    retweet_count          created_at           source  reply_to_status  \
# 0             29 2023-02-03 12:38:39  Twitter Web App              NaN
# 1             30 2023-02-03 12:23:56  Twitter Web App              NaN
# 2            137 2023-02-03 10:48:58  Twitter Web App              NaN
# 3             21 2023-02-03 06:20:00  Twitter Web App              NaN
# 4             38 2023-02-03 06:05:00  Twitter Web App              NaN
#
#   reply_to_user  retweets  favorites
# 0          None        29        511
# 1          None        30        515
# 2          None       137       2447
# 3          None        21        442
# 4          None        38       1013

# %% [markdown]
# #### Most used Hashtags

# %%
def hashtag_extract(x):
    hashtags = []
    ht = re.findall(r"#(\w+)", x)
    hashtags.extend(ht)
    if hashtags==[]:
        return ''
    return hashtags

# %%
tags=[hashtag_extract(x) for  x in data.text]

# %%
all_tags=[]
for tag in tags:
    if tag!='':
        all_tags.extend(tag)

# %%
tags_vc={tag:0 for tag in set(all_tags)}

# %%
for tweet in data.text:
    ht = re.findall(r"#(\w+)", tweet)
    if ht!=[]:
        for tag in ht:
            tags_vc[tag]+=1

# %%
tags_vc_sorted=dict(sorted(tags_vc.items(),key= lambda x:x[1],reverse=True))

# %%
tags_vc_sorted
# Out:
# {'INDvNZ': 274,
#  'OneFamily': 124,
#  'TeamIndia': 120,
#  'WhistlePodu': 118,
#  'PlayBold': 92,
#  'LucknowSuperGiants': 87,
#  'LSG': 84,
#  'IPLAuction': 62,
#  'Yellove': 41,
#  'PunjabKings': 40,
#  'IPL2023': 39,
#  'iplt20livecricket': 37,
#  'TATAIPL': 36,
#  'AavaDe': 34,
#  'GujaratTitans': 34,
#  'ipl': 33,
#  'INDvSL': 31,
#  'SuperFam': 31,
#  'U19T20WorldCup': 28,
#  'iplt20score': 28,
#  'iplscore': 28,
#  'ipllivescore': 27,
#  'OnThisDay': 26,
#  'RanjiTrophy': 26,
#  'iplt20livecricketscore': 25,
#  'SaddaPunjab': 19,
#  'ipllivematch': 19,
#  'Whistle4Blue': 19,
#  'SuperGiant': 16,
#  'SherSquad': 16,
#  'DD': 16,
#  'iplt20': 14,
#  'RPSvDD': 12,
#  'IPL2022': 12,
#  'DDvSRH': 11,
#  'IPL': 10,
#  'SuperGiants': 10,
#  'ipl9': 10,
#  'DDvRPS': 10,
#  'ipllivecricket': 8,
#  'IPLFinal': 8,
#  'ShubmanGill': 7,
#  'BhaukaalMachaDenge': 6,
#  'DDvKKR': 6,
#  'RohitSharma': 6,
#  'SA20': 5,
#  'DDvMI': 5,
#  'RCB': 5,
#  'DSG': 5,
#  'iplt20live': 5,
#  'RCBvDD': 5,
#  'SeasonOfFirsts': 5,
#  'IPL2017': 5,
#  'GTvRR': 4,
#  'MumbaiIndians': 4,
#  'TheRoarStartsHere': 4,
#  'AbKiskiBaariHai': 4,
#  'RCBvsGT': 4,
#  'ipllive': 3,
#  'SuperBirthday': 3,
#  'INDvAUS': 3,
#  'DelhiCapitals': 3,
#  'DurbansSuperGiants': 3,
#  'WPL': 3,
#  'iplmatchscore': 3,
#  'KXIP': 3,
#  'OTD': 3,
#  'WhistleForJoburg': 3,
#  'ICCAwards': 3,
#  'IPLFinals': 3,
#  'ICCRankings': 2,
#  'DDvKXIP': 2,
#  'DDvGL': 2,
#  'SheIsBold': 2,
#  'GUJARATITANS': 2,
#  'MSDhoni': 2,
#  'CricketTwitter': 2,
#  'RashidKhan': 2,
#  'TitansWay': 2,
#  'IPL2022AUCTION': 2,
#  'WeAreChallengers': 2,
#  'YelloveForever': 2,
#  'DilKholKe': 2,
#  'Winners': 2,
#  'ViratKohli': 2,
#  'ICYMI': 2,
#  '1': 2,
#  'JaydevUnadkat': 2,
#  'WhistlePoduForever': 2,
#  'IPLLiveCricket': 2,
#  'ChennaiSuperKlicks': 2,
#  'Pathaan': 2,
#  'RRvGT': 2,
#  'SherOfTheWeek': 2,
#  'DavidMiller': 2,
#  'MICapeTown': 2,
#  'SikandarRaza': 2,
#  'Champions': 2,
#  'iplt2': 2,
#  'AndhaNaalGnyabagam': 2,
#  'PAKvNZ': 2,
#  'KKR': 2,
#  'iplliveupdate': 2,
#  'IPL2019': 2,
#  'ArshdeepSingh': 2,
#  'Rahultewatia': 2,
#  'TooObvious': 1,
#  'IPLSchedul': 1,
#  'VIVOIPL2017Schedule': 1,
#  'U19T20WC': 1,
#  'GujaratFam': 1,
#  'gujaratLions': 1,
#  'MondayMotivation': 1,
#  'T20WorldCup': 1,
#  'SunrisersHyderabad': 1,
#  'IPLRankings': 1,
#  'WomenInBlue': 1,
#  'IPLauctionPlayers': 1,
#  'JustSaying': 1,
#  'IPL2023Auction': 1,
#  'ItsHerGameToo': 1,
#  'DC': 1,
#  'Ipllivecricketscore': 1,
#  'Gujaratlions': 1,
#  'WPLAuction': 1,
#  'Top10of2': 1,
#  'daredevils': 1,
#  'MenInBlue': 1,
#  'Shubmangill': 1,
#  'DDvsKXIP': 1,
#  'bangalore': 1,
#  'IPLStadiums': 1,
#  'IPLauction2017': 1,
#  'DSGvJSK': 1,
#  'AbApniBaariHai': 1,
#  'SeasonofFirsts': 1,
#  'HockeyWorldCup': 1,
#  'CaptainVibing': 1,
#  'ShivamMavi': 1,
#  'RCBvGT': 1,
#  'IPl': 1,
#  'INDvENG': 1,
#  'INDWvUAEW': 1,
#  'RishabhPant': 1,
#  'U19WorldCup': 1,
#  'GautamGambhir': 1,
#  'IPLWicketTakers': 1,
#  'KXIPvDD': 1,
#  'daredevilsscore': 1,
#  'SwapnilSingh': 1,
#  'GLvDD': 1,
#  'DelhiDaredevils': 1,
#  'iplt9': 1,
#  'NewProfilePic': 1,
#  'iplAuction2017': 1,
#  'PRvDSG': 1,
#  'ILT20': 1,
#  'IPLli': 1,
#  'micapetown': 1,
#  'IPLpointtable': 1,
#  'IPLPlayoffs': 1,
#  'LearnBold': 1,
#  'daredevilsteampoints': 1,
#  'YudhvirSinghCharak': 1,
#  'ODIRankings': 1,
#  'IPLranking': 1,
#  'HockeyWorldCup2023': 1,
#  'RCBNewLogo': 1,
#  'BorderGavaskarTrophy': 1,
#  'NZvIND': 1,
#  'RoyalChallengers': 1,
#  'SuperPongal': 1,
#  'VIVOIPL': 1,
#  'RahulTripathi': 1,
#  'DareDevilsVsKingsXIpunjab': 1,
#  'ipl2017Auction': 1,
#  'iplQualifier': 1,
#  'IPLVenues': 1,
#  'PlayoffsAavaDe': 1,
#  'onefamily': 1,
#  'MondayMood': 1,
#  'TimeToFly': 1,
#  'RisingPuneSupergiants': 1,
#  'HardikPandya': 1,
#  'WhatIf': 1,
#  'DelhiDaredevi': 1,
#  'IPL2020Schedule': 1,
#  'BGT': 1,
#  'Retentions': 1,
#  'ListofPlayers': 1,
#  'Playbold': 1,
#  'Saha': 1,
#  'FirstOverHattrick': 1,
#  'i': 1,
#  'DeepakHooda': 1,
#  'ipl2017': 1,
#  'NEHRAJISupermacy': 1,
#  'DCvCSK': 1,
#  'AavaDE': 1,
#  'MeetTheTitan': 1,
#  'GLvsKKR': 1,
#  'IPL10Venue': 1,
#  'dilliboys': 1,
#  'PCvSEC': 1,
#  'KingsXIpunjab': 1,
#  'IPL2019auction': 1,
#  'IPLMatchVenues': 1,
#  'NGL': 1,
#  'GLvRCB': 1,
#  'HarpreetBrar': 1,
#  'JoginderSharma': 1,
#  'HappyRepublicDay': 1,
#  'IPLTeamRanking': 1,
#  'ip': 1,
#  'ThalaDharisanam': 1,
#  'SAUvDEL': 1,
#  'MIJunior': 1,
#  'MI': 1,
#  'RajasthanRoy': 1,
#  'IPLlive': 1,
#  'GuajratTitans': 1,
#  'INDWvSAW': 1,
#  'ThisIsNewDe': 1,
#  'benstokes': 1,
#  '𝐏𝐥𝐚𝐲𝐂𝐨𝐥𝐝': 1,
#  'WhistlingSince08': 1,
#  'YHPL': 1,
#  'RepublicDayIndia': 1,
#  'T20ITeamOf2022': 1,
#  'IPL10': 1,
#  'SuperConnexions': 1,
#  'iplPoints': 1,
#  'Oscars': 1,
#  'INDvsSL': 1,
#  'MarcusStoinis': 1,
#  'TATAIPLAuction': 1,
#  'IPLliveScore': 1,
#  'ipllivescor': 1,
#  'PlayBol': 1,
#  'AboutLastNight': 1,
#  'BhaukaalMachaDiye': 1,
#  'IPLFixtures': 1,
#  'Bhaukaal': 1,
#  'IPL10Stadiums': 1,
#  'WhistleForIndia': 1,
#  '𝐓𝐞𝐚𝐦𝐈𝐧𝐝𝐢𝐚': 1,
#  'Cricket': 1,
#  'Squad': 1,
#  'TitansFAM': 1,
#  'LSGvGT': 1,
#  'DareDevilsLiveMatchScore': 1,
#  'IPL2019playersauction': 1,
#  'U19CWC': 1,
#  'DareDevils': 1,
#  'iplt': 1,
#  'INDWvSCOW': 1}

# %% [markdown]
# ## Cleaning the Tweet Data

# %% [markdown]
# #### Removing user handle

# %%
# removing user handle 
data['tidy_tweet'] = data['text'].replace(to_replace ='(@[\w]+)', value ='', regex = True) 
data['tidy_tweet'] = data['tidy_tweet'].replace(to_replace =('RT'), value ='',regex = True)

# %%
# Before
tweet_data['text'][:2]
# Out:
# 0    The 𝚑𝚎𝚛𝚘 from the final over of 2007 T20 World...
# 1    The moment that'll forever be etched in our he...
# Name: text, dtype: object

# %%
# After
data['tidy_tweet'][:2]
# Out:
# 0    The 𝚑𝚎𝚛𝚘 from the final over of 2007 T20 World...
# 1    The moment that'll forever be etched in our he...
# Name: tidy_tweet, dtype: object

# %% [markdown]
# #### Remove any links from the tweet

# %%
#remove any links from the tweet: Links not required for performing sentiment analysis.
data['tidy_tweet'] = data['tidy_tweet'].str.replace('((www\.[\s]+)|(https?://[^\s]+))','\0',regex=True)

# %%
# Before
tweet_data['text'][3]
# Out:
# '🗣️ Our Head Coach @markb46 on the 🇿🇦 stars who will be in action soon, in #MumbaiIndians Blue &amp; Gold 💙👊\n\n#OneFamily… https://t.co/OxHLSbWpcf'

# %%
# After
data['tidy_tweet'][3]
# Out:
# '🗣️ Our Head Coach  on the 🇿🇦 stars who will be in action soon, in #MumbaiIndians Blue &amp; Gold 💙👊\n\n#OneFamily… \x00'

# %% [markdown]
# #### Remove special characters, numbers, punctuations:

# %%
# remove special characters, numbers, punctuations: None of them would add any value to the sentiment score.
data['tidy_tweet'] = data['tidy_tweet'].str.replace("[^a-zA-Z]+", " ")
# Out:
# <ipython-input-39-bad412b6a610>:2: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %%
data['tidy_tweet'][0]
# Out:
# 'The from the final over of T World Cup bids adieu to all forms of cricket Happy retirement '

# %%
tweet_data.text[0]
# Out:
# 'The 𝚑𝚎𝚛𝚘 from the final over of 2007 T20 World Cup bids adieu to all forms of cricket! 👏\n\nHappy retirement,… https://t.co/enjSWuiWnT'

# %% [markdown]
# #### Tokenising and removing Stop Words

# %%
data["tidy_tweet"] = data["tidy_tweet"].str.lower()
data["tidy_tweet"] = data["tidy_tweet"].str.split()
data['tidy_tweet']=data['tidy_tweet'].apply(lambda x: [item for item in x if item not in stop])

# %%
data.text[0]
# Out:
# 'The 𝚑𝚎𝚛𝚘 from the final over of 2007 T20 World Cup bids adieu to all forms of cricket! 👏\n\nHappy retirement,… https://t.co/enjSWuiWnT'

# %%
# After
data['tidy_tweet'][0]
# Out:
# ['final',
#  'world',
#  'cup',
#  'bids',
#  'adieu',
#  'forms',
#  'cricket',
#  'happy',
#  'retirement']

# %%
#Alternate Method: Using TweetTokenizer to tokenize the tweet
tt = TweetTokenizer()
s0 = "This is a cooool #dummysmiley: :-) :-P <3 and some arrows < > -> <--"
tt.tokenize(s0)
# Out:
# ['This',
#  'is',
#  'a',
#  'cooool',
#  '#dummysmiley',
#  ':',
#  ':-)',
#  ':-P',
#  '<3',
#  'and',
#  'some',
#  'arrows',
#  '<',
#  '>',
#  '->',
#  '<--']

# %%
def rejoin_words(row):
    my_list = row['tidy_tweet']
    joined_words = ( " ".join(my_list))
    return joined_words

data['tidy_tweet'] = data.apply(rejoin_words, axis=1)

# %%
data['tidy_tweet'][1]
# Out:
# 'moment forever etched hearts courtesy jogindersharma thank memories'

# %% [markdown]
# #### Applying Lemmatization

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
nltk.download('wordnet')
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

data['tidy_tweet'] = data['tidy_tweet'].apply(lemmatize_text)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
data['tidy_tweet']
# Out:
# 0       [final, world, cup, bid, adieu, form, cricket,...
# 1       [moment, forever, etched, heart, courtesy, jog...
# 2       [aptain, ro, en, route, nagpur, bgt, onefamily...
# 3       [head, coach, star, action, soon, mumbaiindian...
# 4                   [tim, bhau, time, bowling, onefamily]
#                               ...
# 1295    [siraj, strike, henry, nicholls, fall, tourist...
# 1296    [finn, allen, fall, duck, shami, first, great,...
# 1297                [action, begun, shami, start, indvnz]
# 1298           [shersquad, happy, decision, toss, indvnz]
# 1299    [toss, update, teamindia, toss, elected, field...
# Name: tidy_tweet, Length: 1300, dtype: object

# %%
def rejoin_words(row):
    my_list = row['tidy_tweet']
    joined_words = ( " ".join(my_list))
    return joined_words

data['tidy_tweet'] = data.apply(rejoin_words, axis=1)

# %%
data['tidy_tweet']
# Out:
# 0       final world cup bid adieu form cricket happy r...
# 1       moment forever etched heart courtesy joginders...
# 2         aptain ro en route nagpur bgt onefamily indvaus
# 3       head coach star action soon mumbaiindians blue...
# 4                         tim bhau time bowling onefamily
#                               ...
# 1295    siraj strike henry nicholls fall tourist press...
# 1296    finn allen fall duck shami first great start i...
# 1297                      action begun shami start indvnz
# 1298                 shersquad happy decision toss indvnz
# 1299    toss update teamindia toss elected field first...
# Name: tidy_tweet, Length: 1300, dtype: object

# %% [markdown]
# #### Function for Cleaning

# %%
# This will only be used in for single tweet
def rejoin_words_text(row):
    my_list = row['Text']
    joined_words = ( " ".join(my_list))
    return joined_words

def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

def cleanText(text):
    text = pd.DataFrame({'Orig':[text]})
    text['Text'] = text.Orig.replace(to_replace ='(@[\w]+)', value ='', regex = True) 
    text.Text = text.Text.replace(to_replace =('RT'), value ='',regex = True) 
    text.Text = text.Text.str.replace('((www\.[\s]+)|(https?://[^\s]+))','\0',regex=True)
    text.Text = text.Text.str.replace("[^a-zA-Z]+", " ")
    text.Text = text.Text.str.lower()
    text.Text = text.Text.str.split()
    text.Text = text.Text.apply(lambda x: [item for item in x if item not in stop])
    text.Text = text.apply(rejoin_words_text, axis=1)
    w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
    lemmatizer = nltk.stem.WordNetLemmatizer()
    text.Text = text.Text.apply(lemmatize_text)
    text.Text = text.apply(rejoin_words_text, axis=1)
    return text.Text[0]

# %% [markdown]
# ### Check the Sentiment using VADER

# %% [markdown]
# Read more at: https://github.com/cjhutto/vaderSentiment

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
out={'neg':[],'neu':[],'pos':[],'compound':[]}

# %%
for i in range(data.shape[0]):
    vader_out=analyzer.polarity_scores(data.tidy_tweet[i])
    for key in vader_out.keys():
        out[key].append(vader_out[key])

# %%
out.keys()
# Out:
# dict_keys(['neg', 'neu', 'pos', 'compound'])

# %%
for key in out.keys():
    data[key]=out[key]

# %%
source=data.groupby('ipl').agg('mean')

# %%
source
# Out:
#                      tweet_id  favorite_count  retweet_count  reply_to_status  \
# ipl
# @ChennaiIPL      1.617456e+18     3736.310000     241.720000     1.617795e+18
# @GujTitansIPL    1.544876e+18        8.125000      86.195000     1.540186e+18
# @LucknowIPL      1.610863e+18      746.905000      80.160000     1.606775e+18
# @PunjabKingsIPL  1.618931e+18      446.720000      22.420000     1.620070e+18
# @RCBTweets       1.617173e+18     4132.433673     213.653061     1.617535e+18
# @Thisisnewdelhi  8.289538e+17        0.788462      60.269231              NaN
# @mipaltan        1.619460e+18     1048.870000      53.595000     1.619805e+18
#
#                    retweets    favorites       neg       neu       pos  \
# ipl
# @ChennaiIPL      241.720000  3736.310000  0.011855  0.792730  0.165420
# @GujTitansIPL     86.195000     8.125000  0.032230  0.723465  0.139305
# @LucknowIPL       80.160000   746.905000  0.012960  0.795120  0.141910
# @PunjabKingsIPL   22.420000   446.720000  0.042685  0.813810  0.128500
# @RCBTweets       213.653061  4132.433673  0.020367  0.784786  0.189745
# @Thisisnewdelhi   60.269231     0.788462  0.003346  0.950135  0.046519
# @mipaltan         53.595000  1048.870000  0.019215  0.834540  0.106250
#
#                  compound
# ipl
# @ChennaiIPL      0.218478
# @GujTitansIPL    0.114513
# @LucknowIPL      0.178205
# @PunjabKingsIPL  0.130513
# @RCBTweets       0.259801
# @Thisisnewdelhi  0.058813
# @mipaltan        0.120289

# %%
source=data.groupby('ipl').agg('mean')
fig=go.Figure()
for ipl in data.ipl.unique():
    fig.add_bar(x=['Negative','Neutral','Positive','Compound'],y=list(source[source.index==ipl][out.keys()].values[0]),name=ipl)
fig.update_layout(title='Average Sentiment Across type of iplcurrencies')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6c69fc08-7b3e-43ac-a91c-c0cf521bf776" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c69fc08-7b3e-43ac-a91c-c0cf521bf776")) {                    Plotly.newPlot(                        "6c69fc08-7b3e-43ac-a91c-c0cf521bf776",                        [{"name":"@mipaltan","x":["Negative","Neutral","Positive","Compound"],"y":[0.019215,0.83454,0.10625,0.1202895],"type":"bar"},{"name":"@RCBTweets","x":["Negative","Neutral","Positive","Compound"],"y":[0.02036734693877551,0.7847857142857143,0.18974489795918367,0.2598010204081633],"type":"bar"},{"name":"@GujTitansIPL","x":["Negative","Neutral","Positive","Compound"],"y":[0.03223,0.723465,0.139305,0.114513],"type":"bar"},{"name":"@ChennaiIPL","x":["Negative","Neutral","Positive","Compound"],"y":[0.011855,0.7927299999999999,0.16542,0.21847750000000002],"type":"bar"},{"name":"@LucknowIPL","x":["Negative","Neutral","Positive","Compound"],"y":[0.012960000000000001,0.79512,0.14191,0.17820450000000002],"type":"bar"},{"name":"@Thisisnewdelhi","x":["Negative","Neutral","Positive","Compound"],"y":[0.003346153846153846,0.9501346153846154,0.04651923076923077,0.058812500000000004],"type":"bar"},{"name":"@PunjabKingsIPL","x":["Negative","Neutral","Positive","Compound"],"y":[0.042685,0.81381,0.1285,0.130513],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"col ...

# %% [markdown]
# #### Wordcloud based on the hashtags

# %%
def word_cloud(wd_list,color):
    plt.figure(figsize=(10,15))
    stopwords = set(STOPWORDS)
    all_words = ' '.join([text for text in wd_list])
    wordcloud = WordCloud(max_font_size=None,stopwords=stopwords, background_color='#fcf4ee', collocations=False,colormap =color,
                  width=750, height=750).generate(all_words)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
tweet_data[tweet_data['ipl']=="@RCBTweets"]
# Out:
#             ipl             tweet_id  \
# 200  @RCBTweets  1621516734346964995
# 201  @RCBTweets  1621487453600366592
# 202  @RCBTweets  1621473483116138496
# 203  @RCBTweets  1621426254116450306
# 204  @RCBTweets  1621396183921852418
# ..          ...                  ...
# 391  @RCBTweets  1613090839340716034
# 392  @RCBTweets  1613034753976074241
# 393  @RCBTweets  1613027553912172547
# 394  @RCBTweets  1613015341424168960
# 395  @RCBTweets  1613000241900290048
#
#                                                   text  favorite_count  \
# 200  It's safe to say you’ll see more of the same f...             566
# 201  This is most of us, everytime we see a 🐶/🐈 \n\...            3046
# 202  Preparations for #INDvAUS underway! ⚡\n\n#Play...             938
# 203  #OnThisDay in 2013, @ABdeVilliers17 scored an ...            1609
# 204  #OnThisDay in 2019, 🇮🇳 completed their first O...            1441
# ..                                                 ...             ...
# 391  #OnThisDay in 2015, 4️⃣6️⃣7️⃣ runs were scored...            1746
# 392  #OnThisDay in 2010, Virat Kohli won his first ...            5799
# 393  #PlayBold #TeamIndia #INDvSL https://t.co/NRWg...            1231
# 394  𝗦𝗡𝗔𝗣𝗦𝗛𝗢𝗧𝗦 📸\n\nAn aggressive start by the 🇮🇳 o...            3640
# 395  Here's wishing one of the greatest torchbearer...            3822
#
#      retweet_count          created_at              source  reply_to_status  \
# 200             38 2023-02-03 14:31:30  Twitter for iPhone              NaN
# 201            139 2023-02-03 12:35:09  Twitter for iPhone              NaN
# 202             40 2023-02-03 11:39:38  Twitter for iPhone              NaN
# 203             80 2023-02-03 08:31:58  Twitter for iPhone              NaN
# 204             42 2023-02-03 06:32:28  Twitter for iPhone              NaN
# ..             ...                 ...                 ...              ...
# 391             51 2023-01-11 08:30:00     Twitter Web App              NaN
# 392            240 2023-01-11 04:47:08     Twitter Web App              NaN
# 393             34 2023-01-11 04:18:32     Twitter Web App     1.613015e+18
# 394            176 2023-01-11 03:30:00     Twitter Web App              NaN
# 395            198 2023-01-11 02:30:00     Twitter Web App              NaN
#
#     reply_to_user  retweets  favorites
# 200          None        38        566
# 201          None       139       3046
# 202          None        40        938
# 203          None        80       1609
# 204          None        42       1441
# ..            ...       ...        ...
# 391          None        51       1746
# 392          None       240       5799
# 393     RCBTweets        34       1231
# 394          None       176       3640
# 395          None       198       3822
#
# [196 rows x 11 columns]

# %%
for key in out.keys():
    pos_tags = data['text'][data[key]>0.2].apply(hashtag_extract)
    sentiment_tags=[]
    for tag in pos_tags:
        if tag!='':
            sentiment_tags.extend(tag)
    color={'neg':Reds,'pos':Greens,'neu':Greys,'compound':Purples}
    word_cloud(sentiment_tags,color[key])
