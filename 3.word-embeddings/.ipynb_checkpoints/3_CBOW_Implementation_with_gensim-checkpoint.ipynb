# %%
# !pip install gensim
# !pip install python-Levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.8/dist-packages (3.6.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.8/dist-packages (from gensim) (6.3.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.21.6)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.7.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.20.9-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.20.9
#   Downloading Levenshtein-0.20.9-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      |████████████████████████████████| 174 kB 13.8 MB/s
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 16.2 MB/s
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.20.9 python-Levenshtein-0.20.9 rapidfuzz-2.13.7

# %%
# !wget http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Cell_Phones_and_Accessories_5.json.gz
# Out:
# --2022-12-26 16:59:14--  http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Cell_Phones_and_Accessories_5.json.gz
# Resolving snap.stanford.edu (snap.stanford.edu)... 171.64.75.80
# Connecting to snap.stanford.edu (snap.stanford.edu)|171.64.75.80|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45409631 (43M) [application/x-gzip]
# Saving to: ‘reviews_Cell_Phones_and_Accessories_5.json.gz’
#
# reviews_Cell_Phones 100%[===================>]  43.31M  13.5MB/s    in 4.9s
#
# 2022-12-26 16:59:19 (8.78 MB/s) - ‘reviews_Cell_Phones_and_Accessories_5.json.gz’ saved [45409631/45409631]

# %%
# !gunzip reviews_Cell_Phones_and_Accessories_5.json.gz

# %%
import gensim
import pandas as pd

# %%
df = pd.read_json("/content/reviews_Cell_Phones_and_Accessories_5.json",lines=True)
df.head()
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...        4
# 1  These stickers work like the review says they ...        5
# 2  These are awesome and make my phone look so st...        5
# 3  Item arrived in great time and was in perfect ...        4
# 4  awesome! stays on, and looks great. can be use...        5
#
#                                      summary  unixReviewTime   reviewTime
# 0                                 Looks Good      1400630400  05 21, 2014
# 1                      Really great product.      1389657600  01 14, 2014
# 2                             LOVE LOVE LOVE      1403740800  06 26, 2014
# 3                                      Cute!      1382313600  10 21, 2013
# 4  leopard home button sticker for iphone 4s      1359849600   02 3, 2013

# %%
df.shape
# Out:
# (194439, 9)

# %% [markdown]
# # Preprocessing & Tokenization

# %%
df['reviewText'][0]
# Out:
# "They look good and stick good! I just don't like the rounded shape because I was always bumping it and Siri kept popping up and it was irritating. I just won't buy a product like this again"

# %%
gensim.utils.simple_preprocess("They look good and stick good! I just don't like the rounded shape because I was always bumping it and Siri kept popping up and it was irritating. I just won't buy a product like this again")
# Out:
# ['they',
#  'look',
#  'good',
#  'and',
#  'stick',
#  'good',
#  'just',
#  'don',
#  'like',
#  'the',
#  'rounded',
#  'shape',
#  'because',
#  'was',
#  'always',
#  'bumping',
#  'it',
#  'and',
#  'siri',
#  'kept',
#  'popping',
#  'up',
#  'and',
#  'it',
#  'was',
#  'irritating',
#  'just',
#  'won',
#  'buy',
#  'product',
#  'like',
#  'this',
#  'again']

# %%
review_text = df['reviewText'].apply(gensim.utils.simple_preprocess)
review_text.head()
# Out:
# 0    [they, look, good, and, stick, good, just, don...
# 1    [these, stickers, work, like, the, review, say...
# 2    [these, are, awesome, and, make, my, phone, lo...
# 3    [item, arrived, in, great, time, and, was, in,...
# 4    [awesome, stays, on, and, looks, great, can, b...
# Name: reviewText, dtype: object

# %% [markdown]
# # Train the Word2Vec Model

# %%
model = gensim.models.Word2Vec(window=10,
                               size=100,
                               min_count=2,
                               sg=0)

# %% [markdown]
# # Build the Vocabulory

# %%
model.build_vocab(review_text)

# %%
model.epochs
# Out:
# 5

# %%
model.window
# Out:
# 10

# %% [markdown]
# # Train Word2Vec Model

# %%
model.train(review_text, total_examples=model.corpus_count, epochs = model.epochs)
# Out:
# (61506984, 83868975)

# %%
model.corpus_count
# Out:
# 194439

# %% [markdown]
# # Save the Model

# %%
model.save("./final_word2vec.model")

# %% [markdown]
# # Find the Similar Words and Similarity between the words

# %%
# Word Embeddings
model.wv.most_similar("bad")
# Out:
# [('terrible', 0.6814991235733032),
#  ('shabby', 0.6416946053504944),
#  ('good', 0.5906801223754883),
#  ('horrible', 0.5831505060195923),
#  ('crappy', 0.5313066840171814),
#  ('funny', 0.5232121348381042),
#  ('okay', 0.515824019908905),
#  ('cheap', 0.5148144364356995),
#  ('poor', 0.5127561092376709),
#  ('disappointing', 0.507981538772583)]

# %%
model.wv.similarity(w1='cheap',w2 = 'inexpensive')
# Out:
# 0.5293849

# %%
matrix = model.wv.vectors # extract the word embedding matrix

print(f"shape of the word embedding matrix is {matrix.shape}")
# Out:
# shape of the word embedding matrix is (35561, 100)

# %%
W_out = model.trainables.syn1neg
W_out.shape # Output weights
# Out:
# (35561, 100)

# %%
vocab_list = list(model.wv.vocab.keys())

# %%
len(vocab_list)
# Out:
# 35561

# %%
vocab_list
# Out:
# ['they',
#  'look',
#  'good',
#  'and',
#  'stick',
#  'just',
#  'don',
#  'like',
#  'the',
#  'rounded',
#  'shape',
#  'because',
#  'was',
#  'always',
#  'bumping',
#  'it',
#  'siri',
#  'kept',
#  'popping',
#  'up',
#  'irritating',
#  'won',
#  'buy',
#  'product',
#  'this',
#  'again',
#  'these',
#  'stickers',
#  'work',
#  'review',
#  'says',
#  'do',
#  'on',
#  'great',
#  'stay',
#  'phone',
#  'are',
#  'super',
#  'stylish',
#  'can',
#  'share',
#  'them',
#  'with',
#  'my',
#  'sister',
#  'awesome',
#  'make',
#  'so',
#  'have',
#  'only',
#  'used',
#  'one',
#  'far',
#  'had',
#  'for',
#  'almost',
#  'year',
#  'you',
#  'believe',
#  'that',
#  'quality',
#  'item',
#  'arrived',
#  'in',
#  'time',
#  'perfect',
#  'condition',
#  'however',
#  'ordered',
#  'buttons',
#  'were',
#  'deal',
#  'included',
#  'free',
#  'screen',
#  'protector',
#  'never',
#  'received',
#  'though',
#  'its',
#  'not',
#  'big',
#  'would',
#  've',
#  'been',
#  'nice',
#  'to',
#  'get',
#  'since',
#  'claim',
#  'comes',
#  'stays',
#  'looks',
#  'be',
#  'multiple',
#  'apple',
#  'products',
#  'especially',
#  'having',
#  'nails',
#  'helps',
#  'an',
#  'elevated',
#  'key',
#  'using',
#  'home',
#  'button',
#  'easy',
#  'daughter',
#  'both',
#  'purchase',
#  'well',
#  'worth',
#  'price',
#  'came',
#  'as',
#  'described',
#  'doesn',
#  'come',
#  'unstuck',
#  'cute',
#  'people',
#  'ask',
#  'where',
#  'got',
#  'from',
#  'when',
#  'driving',
#  'worked',
#  'first',
#  'week',
#  'then',
#  'charge',
#  'is',
#  'waste',
#  'of',
#  'money',
#  'case',
#  'solid',
#  'build',
#  'protects',
#  'all',
#  'around',
#  'access',
#  'battery',
#  'charges',
#  'full',
#  'lasts',
#  'me',
#  'day',
#  'usually',
#  'leave',
#  'house',
#  'am',
#  'return',
#  'at',
#  'pm',
#  'glad',
#  'start',
#  'end',
#  'fantastic',
#  'very',
#  'features',
#  'without',
#  'any',
#  'loss',
#  'reception',
#  'but',
#  'most',
#  'importantly',
#  'double',
#  'power',
#  'promised',
#  'fits',
#  'perfectly',
#  'keeps',
#  'powerd',
#  'complain',
#  'recommend',
#  'galaxy',
#  'slim',
#  'add',
#  'much',
#  'weight',
#  'doubles',
#  'life',
#  'either',
#  'or',
#  'there',
#  'handy',
#  'off',
#  'switch',
#  'leds',
#  'indicate',
#  'level',
#  'packaged',
#  'performs',
#  'exactly',
#  'advertised',
#  'sturdily',
#  'built',
#  'provides',
#  'lots',
#  'boost',
#  'does',
#  'what',
#  'supposed',
#  'too',
#  'insert',
#  'out',
#  'definitely',
#  'star',
#  'experience',
#  'know',
#  'love',
#  'unlike',
#  'rechargeable',
#  'cases',
#  'powerbear',
#  'whole',
#  'days',
#  'heat',
#  'other',
#  'ones',
#  'completely',
#  'fascinated',
#  'by',
#  'ultra',
#  'light',
#  'sleek',
#  'design',
#  'before',
#  'mophie',
#  'couldn',
#  'wear',
#  'often',
#  'hot',
#  'brick',
#  'your',
#  'pocket',
#  'hence',
#  'contrary',
#  'take',
#  'even',
#  'tell',
#  'difference',
#  'also',
#  'strong',
#  'manner',
#  'dropped',
#  'few',
#  'times',
#  'shock',
#  'resistant',
#  'technology',
#  'let',
#  'single',
#  'thing',
#  'happen',
#  'became',
#  'extension',
#  'night',
#  'more',
#  'than',
#  'two',
#  'shocked',
#  'hear',
#  'positive',
#  'compliments',
#  'hearing',
#  'job',
#  'fitness',
#  'center',
#  'throughout',
#  'community',
#  'everybody',
#  'loving',
#  'cost',
#  'cheaper',
#  'brand',
#  'best',
#  'made',
#  'internet',
#  'going',
#  'family',
#  'holidays',
#  'thank',
#  'needed',
#  'myself',
#  'sons',
#  'new',
#  'replacement',
#  'batteries',
#  'now',
#  'isn',
#  'thanks',
#  'no',
#  'outlets',
#  'chargers',
#  'near',
#  'rescue',
#  'husband',
#  'works',
#  'crazy',
#  'definetly',
#  'thats',
#  'why',
#  'wife',
#  'wonder',
#  'called',
#  'bear',
#  'surprisingly',
#  'inexpensive',
#  'version',
#  'reliably',
#  'expensive',
#  'variety',
#  'has',
#  'working',
#  'months',
#  'problem',
#  'excellent',
#  'value',
#  'tested',
#  'against',
#  'griffin',
#  'dual',
#  'output',
#  'unit',
#  'checked',
#  'charging',
#  'current',
#  'note',
#  'ma',
#  'long',
#  'bought',
#  'cheap',
#  'actually',
#  'seem',
#  'provide',
#  'high',
#  'idea',
#  'how',
#  'last',
#  'assume',
#  'will',
#  'fine',
#  'did',
#  'testing',
#  'stock',
#  'charger',
#  'passed',
#  'stocked',
#  'couple',
#  'weeks',
#  'stopped',
#  'basically',
#  'small',
#  'ports',
#  'ipod',
#  'who',
#  'wants',
#  'putting',
#  'many',
#  'things',
#  'socket',
#  'convenient',
#  'store',
#  'need',
#  'find',
#  'another',
#  'amps',
#  'ipads',
#  'hp',
#  'touchpads',
#  'compact',
#  'nothing',
#  'special',
#  'sure',
#  'powered',
#  'led',
#  'glows',
#  'able',
#  'phones',
#  'once',
#  'car',
#  'which',
#  'several',
#  'vehicle',
#  'keep',
#  'each',
#  'frustrating',
#  'finding',
#  'sudden',
#  'quits',
#  'way',
#  'recharge',
#  'little',
#  'skeptical',
#  'after',
#  'tried',
#  'lasted',
#  'about',
#  'if',
#  'changes',
#  'update',
#  'disappointed',
#  'didn',
#  'ipad',
#  'buying',
#  'adapter',
#  'cheaply',
#  'china',
#  'radio',
#  'gets',
#  'static',
#  'stop',
#  'lines',
#  'station',
#  'away',
#  'rf',
#  'shielding',
#  'gave',
#  'stars',
#  'listen',
#  'might',
#  'consider',
#  'side',
#  'yo',
#  'order',
#  'timely',
#  'fashion',
#  'terribly',
#  'subaru',
#  'console',
#  'passengers',
#  'emits',
#  'blue',
#  'glow',
#  'held',
#  'abuse',
#  'over',
#  'years',
#  'bough',
#  'different',
#  'wouldn',
#  'jack',
#  'give',
#  'connect',
#  'cables',
#  'overheated',
#  'burning',
#  'fuses',
#  'purchased',
#  'same',
#  'bad',
#  'dont',
#  'wait',
#  'finish',
#  'her',
#  'looking',
#  'waited',
#  'piece',
#  'plastic',
#  'crap',
#  'shouldn',
#  'expected',
#  'handling',
#  'announced',
#  'reached',
#  'shown',
#  'everything',
#  'we',
#  'put',
#  'our',
#  'together',
#  'use',
#  'usb',
#  'devices',
#  'think',
#  'counseling',
#  'haven',
#  'problems',
#  'yrs',
#  'month',
#  'ago',
#  'pros',
#  'loved',
#  'cool',
#  'feature',
#  'plug',
#  'into',
#  'lighter',
#  'con',
#  'top',
#  'clear',
#  'easily',
#  'overtime',
#  'tape',
#  'total',
#  'cons',
#  'could',
#  'tab',
#  'recognize',
#  'port',
#  'while',
#  'iphone',
#  'tablet',
#  'stronger',
#  'still',
#  'touch',
#  'samsung',
#  'outlet',
#  'low',
#  'profile',
#  'tablets',
#  'smartphones',
#  'bluetooth',
#  'speakers',
#  'headsets',
#  'anyone',
#  'universal',
#  'although',
#  'subsequently',
#  'died',
#  'bottom',
#  'slot',
#  'lower',
#  'presumably',
#  'holds',
#  'tight',
#  'some',
#  'loose',
#  'android',
#  'except',
#  'ready',
#  'sockets',
#  'tightly',
#  'fit',
#  'pretty',
#  'construction',
#  'less',
#  'really',
#  'enjoyed',
#  'rapidly',
#  'charged',
#  'friends',
#  'makes',
#  'else',
#  'their',
#  'device',
#  'unless',
#  'remove',
#  'cord',
#  'course',
#  'go',
#  'back',
#  'began',
#  'notice',
#  'flickering',
#  'later',
#  'quit',
#  'permanently',
#  'faulty',
#  'wiring',
#  'guess',
#  'll',
#  'thought',
#  'getting',
#  'better',
#  'maybe',
#  'simply',
#  'disposable',
#  'short',
#  'period',
#  'whatever',
#  'reason',
#  'forced',
#  'found',
#  'range',
#  'yet',
#  'gps',
#  'wallet',
#  'test',
#  'minutes',
#  'felt',
#  'pulled',
#  'smelled',
#  'burnt',
#  'careful',
#  'fire',
#  'hazard',
#  'potentially',
#  'destroy',
#  'electrical',
#  'system',
#  'portable',
#  'must',
#  'pair',
#  'extra',
#  'spare',
#  'seems',
#  'quicker',
#  'dying',
#  'gs',
#  'htc',
#  'evo',
#  'something',
#  'various',
#  'retailers',
#  'anonymous',
#  'chinese',
#  'factory',
#  'alike',
#  're',
#  'deliver',
#  'say',
#  'expect',
#  'qc',
#  'forever',
#  'active',
#  'daily',
#  'par',
#  'suddenly',
#  'die',
#  'replacements',
#  'hand',
#  'yes',
#  'every',
#  'indicates',
#  'plugged',
#  'correctly',
#  'helpful',
#  'rental',
#  'cars',
#  'travel',
#  'behind',
#  'hey',
#  'totally',
#  'pleased',
#  'clever',
#  'gems',
#  'complaints',
#  'hope',
#  'happy',
#  'trails',
#  'smaller',
#  'shipping',
#  'took',
#  'longer',
#  'bright',
#  'annoying',
#  'overall',
#  'feels',
#  'rubber',
#  'sweet',
#  'wears',
#  'paint',
#  'under',
#  'sealant',
#  'anything',
#  'effect',
#  'rubbing',
#  'quite',
#  'worried',
#  'picture',
#  'description',
#  'page',
#  'changing',
#  'desireable',
#  'green',
#  'orange',
#  'cover',
#  'alas',
#  'earlier',
#  'beautiful',
#  'pink',
#  'rubberized',
#  'greasy',
#  'armor',
#  'gorgeous',
#  'change',
#  'white',
#  'silver',
#  'arrive',
#  'defintiely',
#  'should',
#  'cell',
#  'stores',
#  'mark',
#  'quickly',
#  'vivid',
#  'soft',
#  'durable',
#  'wanting',
#  'old',
#  'feel',
#  'covers',
#  'snazzy',
#  'shortly',
#  'started',
#  'peel',
#  'until',
#  'looked',
#  'missing',
#  'spots',
#  'sometimes',
#  'color',
#  'dark',
#  'person',
#  'isnt',
#  'protection',
#  'lot',
#  'simple',
#  'install',
#  'help',
#  'protect',
#  'liked',
#  'ability',
#  'dose',
#  'scratches',
#  'ive',
#  'didnt',
#  'break',
#  'scratch',
#  'gotten',
#  'complements',
#  'bucks',
#  'spent',
#  'afordable',
#  'peels',
#  'dollor',
#  'mine',
#  'electromaster',
#  'snaps',
#  'drop',
#  'surely',
#  'done',
#  'dollar',
#  'hopes',
#  'show',
#  'want',
#  'protected',
#  'mile',
#  'outter',
#  'box',
#  'favorite',
#  'broken',
#  'horrible',
#  'peeling',
#  'left',
#  'orginal',
#  'skin',
#  'being',
#  'specific',
#  'awhile',
#  'shoes',
#  'considering',
#  'purple',
#  'black',
#  'leopard',
#  'hopefully',
#  'trouble',
#  'cutest',
#  'ever',
#  'apply',
#  'uses',
#  'hem',
#  'sweater',
#  'stretched',
#  'intact',
#  'woo',
#  'hoo',
#  'see',
#  'anymore',
#  'judgement',
#  'woks',
#  'genuine',
#  'blackberry',
#  'incase',
#  'forget',
#  'honestly',
#  'model',
#  'road',
#  'worrying',
#  'losing',
#  'leaving',
#  'meet',
#  'fast',
#  'needs',
#  'patient',
#  'folding',
#  'blades',
#  'models',
#  'adapters',
#  'countries',
#  'specified',
#  'jus',
#  'direct',
#  'wall',
#  'right',
#  'portal',
#  'judy',
#  'bit',
#  'slower',
#  'goes',
#  'tends',
#  'firmly',
#  'affordable',
#  'afford',
#  'lives',
#  'luggage',
#  'quick',
#  'spend',
#  'convenience',
#  'crappy',
#  'length',
#  'tall',
#  'bed',
#  'struggle',
#  'laying',
#  'down',
#  'blocky',
#  'worry',
#  'connecter',
#  'place',
#  'fall',
#  'wiggle',
#  'disconnects',
#  'worn',
#  'issue',
#  'turned',
#  'main',
#  'failed',
#  'cable',
#  'tons',
#  'ad',
#  'making',
#  'thru',
#  'wasn',
#  'expecting',
#  'between',
#  'plus',
#  'second',
#  'kinda',
#  'purchasing',
#  'mean',
#  'figured',
#  'heck',
#  'today',
#  'decided',
#  'try',
#  'timed',
#  'mention',
#  'reviewer',
#  'meant',
#  'saying',
#  'poor',
#  'backup',
#  'sgs',
#  'wonderfully',
#  'highly',
#  'recommended',
#  'here',
#  'future',
#  'rough',
#  'wish',
#  'reach',
#  'passenger',
#  'seat',
#  'comfortably',
#  'coiled',
#  'section',
#  'stress',
#  'realize',
#  'eventually',
#  'girlfriend',
#  'oem',
#  'fanboy',
#  'swooped',
#  'remaining',
#  'slightly',
#  'mail',
#  'report',
#  'sealed',
#  'bags',
#  'part',
#  'kind',
#  'normally',
#  'receive',
#  'refurb',
#  'wrong',
#  'certainly',
#  'argue',
#  'benefits',
#  'vs',
#  'generic',
#  'reliability',
#  'list',
#  'solidly',
#  'verizon',
#  'lame',
#  'issues',
#  'retractable',
#  'thus',
#  'limited',
#  'fail',
#  'town',
#  'name',
#  'carry',
#  'junk',
#  'amazon',
#  'fraction',
#  'pay',
#  'national',
#  'cords',
#  'finally',
#  'local',
#  'verses',
#  'chargingi',
#  'persons',
#  'mo',
#  'cant',
#  'beat',
#  'miss',
#  'labeled',
#  'lights',
#  'happens',
#  'defective',
#  'upsetting',
#  'sit',
#  'hours',
#  'reliable',
#  'motorola',
#  'dependable',
#  'within',
#  'fuse',
#  'blown',
#  'inside',
#  'attempted',
#  'noticed',
#  'apart',
#  'upload',
#  'sum',
#  'juice',
#  'dropping',
#  'repeatedly',
#  'floorboard',
#  'occasionally',
#  'stuffing',
#  'hide',
#  'caused',
#  'failure',
#  'soon',
#  'display',
#  'dollars',
#  'witha',
#  'heavier',
#  'shell',
#  'treat',
#  'delicate',
#  'flower',
#  'sprint',
#  'wanted',
#  'fro',
#  'third',
#  'party',
#  'market',
#  'hasn',
#  'fact',
#  'bargain',
#  'expert',
#  'fireworks',
#  'hotel',
#  'parties',
#  'nexus',
#  'microusb',
#  'three',
#  'originally',
#  'prefectly',
#  'hold',
#  'certain',
#  'instead',
#  'official',
#  'straight',
#  'talk',
#  'flimsy',
#  'feeling',
#  'past',
#  'functioned',
#  'window',
#  'guessing',
#  'knows',
#  'es',
#  'un',
#  'para',
#  'carro',
#  'de',
#  'excelente',
#  'calidad',
#  ...]

# %%
vocab_len = len(vocab_list)
vocab = model.wv.vocab

# %%
vocab
# Out:
# {'they': <gensim.models.keyedvectors.Vocab at 0x7fdde4714430>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7fdde47149a0>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7fdde47145e0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7fdde4714610>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x7fddcbf9fee0>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x7fddcbf9f400>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x7fddcbf9f280>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x7fddcbf9f2b0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x7fddcbf9f8e0>,
#  'rounded': <gensim.models.keyedvectors.Vocab at 0x7fddcbf9f700>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x7fddcbf9fe20>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7fddcbf9fca0>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c040>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c0a0>,
#  'bumping': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c100>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c160>,
#  'siri': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c1c0>,
#  'kept': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c220>,
#  'popping': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c280>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c2e0>,
#  'irritating': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c340>,
#  'won': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c3a0>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c400>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c460>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c4c0>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c520>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c580>,
#  'stickers': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c5e0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c640>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c6a0>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c700>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c760>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c7c0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c820>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c880>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c8e0>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c940>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x7fdd8592c9a0>,
#  'stylish': <gensim.models.keyedvectors.Vocab at 0x7fdd8592ca00>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7fdd8592ca60>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cac0>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cb20>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cb80>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cbe0>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cc40>,
#  'awesome': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cca0>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cd00>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cd60>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cdc0>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7fdd8592ce20>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7fdd8592ce80>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cee0>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cf40>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7fdd8592cfa0>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d040>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d0a0>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d100>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d160>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d1c0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d220>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d280>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d2e0>,
#  'arrived': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d340>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d3a0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d400>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d460>,
#  'condition': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d4c0>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d520>,
#  'ordered': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d580>,
#  'buttons': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d5e0>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d640>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d6a0>,
#  'included': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d700>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d760>,
#  'screen': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d7c0>,
#  'protector': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d820>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d880>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d8e0>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d940>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7fdd8592d9a0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7fdd8592da00>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x7fdd8592da60>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7fdd8592dac0>,
#  've': <gensim.models.keyedvectors.Vocab at 0x7fdd8592db20>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7fdd8592db80>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x7fdd8592dbe0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7fdd8592dc40>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x7fdd8592dca0>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7fdd8592dd00>,
#  'claim': <gensim.models.keyedvectors.Vocab at 0x7fdd8592dd60>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x7fdd8592ddc0>,
#  'stays': <gensim.models.keyedvectors.Vocab at 0x7fdd8592de20>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x7fdd8592de80>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7fdd8592dee0>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x7fdd8592df40>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x7fdd8592dfa0>,
#  'products': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f040>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f0a0>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f100>,
#  'nails': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f160>,
#  'helps': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f1c0>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f220>,
#  'elevated': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f280>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f2e0>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f340>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f3a0>,
#  'button': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f400>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f460>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f4c0>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f520>,
#  'purchase': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f580>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f5e0>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f640>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f6a0>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f700>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f760>,
#  'described': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f7c0>,
#  'doesn': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f820>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f880>,
#  'unstuck': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f8e0>,
#  'cute': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f940>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7fdd8592f9a0>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fa00>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fa60>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fac0>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fb20>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fb80>,
#  'driving': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fbe0>,
#  'worked': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fc40>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fca0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fd00>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fd60>,
#  'charge': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fdc0>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fe20>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fe80>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7fdd8592fee0>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x7fdd8592ff40>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7fdd8592ffa0>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x7fdd85930040>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7fdd859300a0>,
#  'protects': <gensim.models.keyedvectors.Vocab at 0x7fdd85930100>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7fdd85930160>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x7fdd859301c0>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x7fdd85930220>,
#  'battery': <gensim.models.keyedvectors.Vocab at 0x7fdd85930280>,
#  'charges': <gensim.models.keyedvectors.Vocab at 0x7fdd859302e0>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7fdd85930340>,
#  'lasts': <gensim.models.keyedvectors.Vocab at 0x7fdd859303a0>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x7fdd85930400>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7fdd85930460>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x7fdd859304c0>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x7fdd85930520>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x7fdd85930580>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x7fdd859305e0>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x7fdd85930640>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7fdd859306a0>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x7fdd85930700>,
#  'glad': <gensim.models.keyedvectors.Vocab at 0x7fdd85930760>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x7fdd859307c0>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7fdd85930820>,
#  'fantastic': <gensim.models.keyedvectors.Vocab at 0x7fdd85930880>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7fdd859308e0>,
#  'features': <gensim.models.keyedvectors.Vocab at 0x7fdd85930940>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7fdd859309a0>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7fdd85930a00>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x7fdd85930a60>,
#  'reception': <gensim.models.keyedvectors.Vocab at 0x7fdd85930ac0>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7fdd85930b20>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7fdd85930b80>,
#  'importantly': <gensim.models.keyedvectors.Vocab at 0x7fdd85930be0>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x7fdd85930c40>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x7fdd85930ca0>,
#  'promised': <gensim.models.keyedvectors.Vocab at 0x7fdd85930d00>,
#  'fits': <gensim.models.keyedvectors.Vocab at 0x7fdd85930d60>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x7fdd85930dc0>,
#  'keeps': <gensim.models.keyedvectors.Vocab at 0x7fdd85930e20>,
#  'powerd': <gensim.models.keyedvectors.Vocab at 0x7fdd85930e80>,
#  'complain': <gensim.models.keyedvectors.Vocab at 0x7fdd85930ee0>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x7fdd85930f40>,
#  'galaxy': <gensim.models.keyedvectors.Vocab at 0x7fdd85930fa0>,
#  'slim': <gensim.models.keyedvectors.Vocab at 0x7fdd85932040>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x7fdd859320a0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7fdd85932100>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x7fdd85932160>,
#  'doubles': <gensim.models.keyedvectors.Vocab at 0x7fdd859321c0>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7fdd85932220>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7fdd85932280>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7fdd859322e0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7fdd85932340>,
#  'handy': <gensim.models.keyedvectors.Vocab at 0x7fdd859323a0>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x7fdd85932400>,
#  'switch': <gensim.models.keyedvectors.Vocab at 0x7fdd85932460>,
#  'leds': <gensim.models.keyedvectors.Vocab at 0x7fdd859324c0>,
#  'indicate': <gensim.models.keyedvectors.Vocab at 0x7fdd85932520>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7fdd85932580>,
#  'packaged': <gensim.models.keyedvectors.Vocab at 0x7fdd859325e0>,
#  'performs': <gensim.models.keyedvectors.Vocab at 0x7fdd85932640>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x7fdd859326a0>,
#  'advertised': <gensim.models.keyedvectors.Vocab at 0x7fdd85932700>,
#  'sturdily': <gensim.models.keyedvectors.Vocab at 0x7fdd85932760>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x7fdd859327c0>,
#  'provides': <gensim.models.keyedvectors.Vocab at 0x7fdd85932820>,
#  'lots': <gensim.models.keyedvectors.Vocab at 0x7fdd85932880>,
#  'boost': <gensim.models.keyedvectors.Vocab at 0x7fdd859328e0>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7fdd85932940>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x7fdd859329a0>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x7fdd85932a00>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x7fdd85932a60>,
#  'insert': <gensim.models.keyedvectors.Vocab at 0x7fdd85932ac0>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7fdd85932b20>,
#  'definitely': <gensim.models.keyedvectors.Vocab at 0x7fdd85932b80>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x7fdd85932be0>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7fdd85932c40>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x7fdd85932ca0>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x7fdd85932d00>,
#  'unlike': <gensim.models.keyedvectors.Vocab at 0x7fdd85932d60>,
#  'rechargeable': <gensim.models.keyedvectors.Vocab at 0x7fdd85932dc0>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x7fdd85932e20>,
#  'powerbear': <gensim.models.keyedvectors.Vocab at 0x7fdd85932e80>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x7fdd85932ee0>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7fdd85932f40>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x7fdd85932fa0>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7fdd85934040>,
#  'ones': <gensim.models.keyedvectors.Vocab at 0x7fdd859340a0>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x7fdd85934100>,
#  'fascinated': <gensim.models.keyedvectors.Vocab at 0x7fdd85934160>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7fdd859341c0>,
#  'ultra': <gensim.models.keyedvectors.Vocab at 0x7fdd85934220>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7fdd85934280>,
#  'sleek': <gensim.models.keyedvectors.Vocab at 0x7fdd859342e0>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7fdd85934340>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7fdd859343a0>,
#  'mophie': <gensim.models.keyedvectors.Vocab at 0x7fdd85934400>,
#  'couldn': <gensim.models.keyedvectors.Vocab at 0x7fdd85934460>,
#  'wear': <gensim.models.keyedvectors.Vocab at 0x7fdd859344c0>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7fdd85934520>,
#  'hot': <gensim.models.keyedvectors.Vocab at 0x7fdd85934580>,
#  'brick': <gensim.models.keyedvectors.Vocab at 0x7fdd859345e0>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x7fdd85934640>,
#  'pocket': <gensim.models.keyedvectors.Vocab at 0x7fdd859346a0>,
#  'hence': <gensim.models.keyedvectors.Vocab at 0x7fdd85934700>,
#  'contrary': <gensim.models.keyedvectors.Vocab at 0x7fdd85934760>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x7fdd859347c0>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7fdd85934820>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x7fdd85934880>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x7fdd859348e0>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7fdd85934940>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7fdd859349a0>,
#  'manner': <gensim.models.keyedvectors.Vocab at 0x7fdd85934a00>,
#  'dropped': <gensim.models.keyedvectors.Vocab at 0x7fdd85934a60>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7fdd85934ac0>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x7fdd85934b20>,
#  'shock': <gensim.models.keyedvectors.Vocab at 0x7fdd85934b80>,
#  'resistant': <gensim.models.keyedvectors.Vocab at 0x7fdd85934be0>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x7fdd85934c40>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x7fdd85934ca0>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7fdd85934d00>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x7fdd85934d60>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x7fdd85934dc0>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x7fdd85934e20>,
#  'extension': <gensim.models.keyedvectors.Vocab at 0x7fdd85934e80>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x7fdd85934ee0>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7fdd85934f40>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7fdd85934fa0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7fdd85935040>,
#  'shocked': <gensim.models.keyedvectors.Vocab at 0x7fdd859350a0>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x7fdd85935100>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x7fdd85935160>,
#  'compliments': <gensim.models.keyedvectors.Vocab at 0x7fdd859351c0>,
#  'hearing': <gensim.models.keyedvectors.Vocab at 0x7fdd85935220>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x7fdd85935280>,
#  'fitness': <gensim.models.keyedvectors.Vocab at 0x7fdd859352e0>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x7fdd85935340>,
#  'throughout': <gensim.models.keyedvectors.Vocab at 0x7fdd859353a0>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x7fdd85935400>,
#  'everybody': <gensim.models.keyedvectors.Vocab at 0x7fdd85935460>,
#  'loving': <gensim.models.keyedvectors.Vocab at 0x7fdd859354c0>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x7fdd85935520>,
#  'cheaper': <gensim.models.keyedvectors.Vocab at 0x7fdd85935580>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x7fdd859355e0>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7fdd85935640>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7fdd859356a0>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x7fdd85935700>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7fdd85935760>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7fdd859357c0>,
#  'holidays': <gensim.models.keyedvectors.Vocab at 0x7fdd85935820>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x7fdd85935880>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x7fdd859358e0>,
#  'myself': <gensim.models.keyedvectors.Vocab at 0x7fdd85935940>,
#  'sons': <gensim.models.keyedvectors.Vocab at 0x7fdd859359a0>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7fdd85935a00>,
#  'replacement': <gensim.models.keyedvectors.Vocab at 0x7fdd85935a60>,
#  'batteries': <gensim.models.keyedvectors.Vocab at 0x7fdd85935ac0>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x7fdd85935b20>,
#  'isn': <gensim.models.keyedvectors.Vocab at 0x7fdd85935b80>,
#  'thanks': <gensim.models.keyedvectors.Vocab at 0x7fdd85935be0>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7fdd85935c40>,
#  'outlets': <gensim.models.keyedvectors.Vocab at 0x7fdd85935ca0>,
#  'chargers': <gensim.models.keyedvectors.Vocab at 0x7fdd85935d00>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x7fdd85935d60>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x7fdd85935dc0>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7fdd85935e20>,
#  'works': <gensim.models.keyedvectors.Vocab at 0x7fdd85935e80>,
#  'crazy': <gensim.models.keyedvectors.Vocab at 0x7fdd85935ee0>,
#  'definetly': <gensim.models.keyedvectors.Vocab at 0x7fdd85935f40>,
#  'thats': <gensim.models.keyedvectors.Vocab at 0x7fdd85935fa0>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x7fdd85937040>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x7fdd859370a0>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7fdd85937100>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7fdd85937160>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x7fdd859371c0>,
#  'surprisingly': <gensim.models.keyedvectors.Vocab at 0x7fdd85937220>,
#  'inexpensive': <gensim.models.keyedvectors.Vocab at 0x7fdd85937280>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x7fdd859372e0>,
#  'reliably': <gensim.models.keyedvectors.Vocab at 0x7fdd85937340>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x7fdd859373a0>,
#  'variety': <gensim.models.keyedvectors.Vocab at 0x7fdd85937400>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7fdd85937460>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x7fdd859374c0>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x7fdd85937520>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7fdd85937580>,
#  'excellent': <gensim.models.keyedvectors.Vocab at 0x7fdd859375e0>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x7fdd85937640>,
#  'tested': <gensim.models.keyedvectors.Vocab at 0x7fdd859376a0>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x7fdd85937700>,
#  'griffin': <gensim.models.keyedvectors.Vocab at 0x7fdd85937760>,
#  'dual': <gensim.models.keyedvectors.Vocab at 0x7fdd859377c0>,
#  'output': <gensim.models.keyedvectors.Vocab at 0x7fdd85937820>,
#  'unit': <gensim.models.keyedvectors.Vocab at 0x7fdd85937880>,
#  'checked': <gensim.models.keyedvectors.Vocab at 0x7fdd859378e0>,
#  'charging': <gensim.models.keyedvectors.Vocab at 0x7fdd85937940>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x7fdd859379a0>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x7fdd85937a00>,
#  'ma': <gensim.models.keyedvectors.Vocab at 0x7fdd85937a60>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7fdd85937ac0>,
#  'bought': <gensim.models.keyedvectors.Vocab at 0x7fdd85937b20>,
#  'cheap': <gensim.models.keyedvectors.Vocab at 0x7fdd85937b80>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x7fdd85937be0>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x7fdd85937c40>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7fdd85937ca0>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7fdd85937d00>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x7fdd85937d60>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7fdd85937dc0>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x7fdd85937e20>,
#  'assume': <gensim.models.keyedvectors.Vocab at 0x7fdd85937e80>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7fdd85937ee0>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x7fdd85937f40>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7fdd85937fa0>,
#  'testing': <gensim.models.keyedvectors.Vocab at 0x7fdd85939040>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x7fdd859390a0>,
#  'charger': <gensim.models.keyedvectors.Vocab at 0x7fdd85939100>,
#  'passed': <gensim.models.keyedvectors.Vocab at 0x7fdd85939160>,
#  'stocked': <gensim.models.keyedvectors.Vocab at 0x7fdd859391c0>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x7fdd85939220>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7fdd85939280>,
#  'stopped': <gensim.models.keyedvectors.Vocab at 0x7fdd859392e0>,
#  'basically': <gensim.models.keyedvectors.Vocab at 0x7fdd85939340>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7fdd859393a0>,
#  'ports': <gensim.models.keyedvectors.Vocab at 0x7fdd85939400>,
#  'ipod': <gensim.models.keyedvectors.Vocab at 0x7fdd85939460>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7fdd859394c0>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x7fdd85939520>,
#  'putting': <gensim.models.keyedvectors.Vocab at 0x7fdd85939580>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7fdd859395e0>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x7fdd85939640>,
#  'socket': <gensim.models.keyedvectors.Vocab at 0x7fdd859396a0>,
#  'convenient': <gensim.models.keyedvectors.Vocab at 0x7fdd85939700>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x7fdd85939760>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7fdd859397c0>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x7fdd85939820>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x7fdd85939880>,
#  'amps': <gensim.models.keyedvectors.Vocab at 0x7fdd859398e0>,
#  'ipads': <gensim.models.keyedvectors.Vocab at 0x7fdd85939940>,
#  'hp': <gensim.models.keyedvectors.Vocab at 0x7fdd859399a0>,
#  'touchpads': <gensim.models.keyedvectors.Vocab at 0x7fdd85939a00>,
#  'compact': <gensim.models.keyedvectors.Vocab at 0x7fdd85939a60>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x7fdd85939ac0>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7fdd85939b20>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x7fdd85939b80>,
#  'powered': <gensim.models.keyedvectors.Vocab at 0x7fdd85939be0>,
#  'led': <gensim.models.keyedvectors.Vocab at 0x7fdd85939c40>,
#  'glows': <gensim.models.keyedvectors.Vocab at 0x7fdd85939ca0>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7fdd85939d00>,
#  'phones': <gensim.models.keyedvectors.Vocab at 0x7fdd85939d60>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x7fdd85939dc0>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x7fdd85939e20>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7fdd85939e80>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7fdd85939ee0>,
#  'vehicle': <gensim.models.keyedvectors.Vocab at 0x7fdd85939f40>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x7fdd85939fa0>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a040>,
#  'frustrating': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a0a0>,
#  'finding': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a100>,
#  'sudden': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a160>,
#  'quits': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a1c0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a220>,
#  'recharge': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a280>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a2e0>,
#  'skeptical': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a340>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a3a0>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a400>,
#  'lasted': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a460>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a4c0>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a520>,
#  'changes': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a580>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a5e0>,
#  'disappointed': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a640>,
#  'didn': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a6a0>,
#  'ipad': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a700>,
#  'buying': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a760>,
#  'adapter': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a7c0>,
#  'cheaply': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a820>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a880>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a8e0>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a940>,
#  'static': <gensim.models.keyedvectors.Vocab at 0x7fdd8593a9a0>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x7fdd8593aa00>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x7fdd8593aa60>,
#  'station': <gensim.models.keyedvectors.Vocab at 0x7fdd8593aac0>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x7fdd8593ab20>,
#  'rf': <gensim.models.keyedvectors.Vocab at 0x7fdd8593ab80>,
#  'shielding': <gensim.models.keyedvectors.Vocab at 0x7fdd8593abe0>,
#  'gave': <gensim.models.keyedvectors.Vocab at 0x7fdd8593ac40>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x7fdd8593aca0>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x7fdd8593ad00>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7fdd8593ad60>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x7fdd8593adc0>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x7fdd8593ae20>,
#  'yo': <gensim.models.keyedvectors.Vocab at 0x7fdd8593ae80>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7fdd8593aee0>,
#  'timely': <gensim.models.keyedvectors.Vocab at 0x7fdd8593af40>,
#  'fashion': <gensim.models.keyedvectors.Vocab at 0x7fdd8593afa0>,
#  'terribly': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc040>,
#  'subaru': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc0a0>,
#  'console': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc100>,
#  'passengers': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc160>,
#  'emits': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc1c0>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc220>,
#  'glow': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc280>,
#  'held': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc2e0>,
#  'abuse': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc340>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc3a0>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc400>,
#  'bough': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc460>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc4c0>,
#  'wouldn': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc520>,
#  'jack': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc580>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc5e0>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc640>,
#  'cables': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc6a0>,
#  'overheated': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc700>,
#  'burning': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc760>,
#  'fuses': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc7c0>,
#  'purchased': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc820>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc880>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc8e0>,
#  'dont': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc940>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7fdd858bc9a0>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x7fdd858bca00>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x7fdd858bca60>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcac0>,
#  'waited': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcb20>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcb80>,
#  'plastic': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcbe0>,
#  'crap': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcc40>,
#  'shouldn': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcca0>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcd00>,
#  'handling': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcd60>,
#  'announced': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcdc0>,
#  'reached': <gensim.models.keyedvectors.Vocab at 0x7fdd858bce20>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7fdd858bce80>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcee0>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcf40>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x7fdd858bcfa0>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7fdd858be040>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7fdd858be0a0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7fdd858be100>,
#  'usb': <gensim.models.keyedvectors.Vocab at 0x7fdd858be160>,
#  'devices': <gensim.models.keyedvectors.Vocab at 0x7fdd858be1c0>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x7fdd858be220>,
#  'counseling': <gensim.models.keyedvectors.Vocab at 0x7fdd858be280>,
#  'haven': <gensim.models.keyedvectors.Vocab at 0x7fdd858be2e0>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x7fdd858be340>,
#  'yrs': <gensim.models.keyedvectors.Vocab at 0x7fdd858be3a0>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x7fdd858be400>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x7fdd858be460>,
#  'pros': <gensim.models.keyedvectors.Vocab at 0x7fdd858be4c0>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x7fdd858be520>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7fdd858be580>,
#  'feature': <gensim.models.keyedvectors.Vocab at 0x7fdd858be5e0>,
#  'plug': <gensim.models.keyedvectors.Vocab at 0x7fdd858be640>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7fdd858be6a0>,
#  'lighter': <gensim.models.keyedvectors.Vocab at 0x7fdd858be700>,
#  'con': <gensim.models.keyedvectors.Vocab at 0x7fdd858be760>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x7fdd858be7c0>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x7fdd858be820>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x7fdd858be880>,
#  'overtime': <gensim.models.keyedvectors.Vocab at 0x7fdd858be8e0>,
#  'tape': <gensim.models.keyedvectors.Vocab at 0x7fdd858be940>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7fdd858be9a0>,
#  'cons': <gensim.models.keyedvectors.Vocab at 0x7fdd858bea00>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7fdd858bea60>,
#  'tab': <gensim.models.keyedvectors.Vocab at 0x7fdd858beac0>,
#  'recognize': <gensim.models.keyedvectors.Vocab at 0x7fdd858beb20>,
#  'port': <gensim.models.keyedvectors.Vocab at 0x7fdd858beb80>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7fdd858bebe0>,
#  'iphone': <gensim.models.keyedvectors.Vocab at 0x7fdd858bec40>,
#  'tablet': <gensim.models.keyedvectors.Vocab at 0x7fdd858beca0>,
#  'stronger': <gensim.models.keyedvectors.Vocab at 0x7fdd858bed00>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7fdd858bed60>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x7fdd858bedc0>,
#  'samsung': <gensim.models.keyedvectors.Vocab at 0x7fdd858bee20>,
#  'outlet': <gensim.models.keyedvectors.Vocab at 0x7fdd858bee80>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x7fdd858beee0>,
#  'profile': <gensim.models.keyedvectors.Vocab at 0x7fdd858bef40>,
#  'tablets': <gensim.models.keyedvectors.Vocab at 0x7fdd858befa0>,
#  'smartphones': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf040>,
#  'bluetooth': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf0a0>,
#  'speakers': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf100>,
#  'headsets': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf160>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf1c0>,
#  'universal': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf220>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf280>,
#  'subsequently': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf2e0>,
#  'died': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf340>,
#  'bottom': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf3a0>,
#  'slot': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf400>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf460>,
#  'presumably': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf4c0>,
#  'holds': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf520>,
#  'tight': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf580>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf5e0>,
#  'loose': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf640>,
#  'android': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf6a0>,
#  'except': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf700>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf760>,
#  'sockets': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf7c0>,
#  'tightly': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf820>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf880>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf8e0>,
#  'construction': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf940>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7fdd858bf9a0>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfa00>,
#  'enjoyed': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfa60>,
#  'rapidly': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfac0>,
#  'charged': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfb20>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfb80>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfbe0>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfc40>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfca0>,
#  'device': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfd00>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfd60>,
#  'remove': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfdc0>,
#  'cord': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfe20>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfe80>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x7fdd858bfee0>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x7fdd858bff40>,
#  'began': <gensim.models.keyedvectors.Vocab at 0x7fdd858bffa0>,
#  'notice': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1040>,
#  'flickering': <gensim.models.keyedvectors.Vocab at 0x7fdd858c10a0>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1100>,
#  'quit': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1160>,
#  'permanently': <gensim.models.keyedvectors.Vocab at 0x7fdd858c11c0>,
#  'faulty': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1220>,
#  'wiring': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1280>,
#  'guess': <gensim.models.keyedvectors.Vocab at 0x7fdd858c12e0>,
#  'll': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1340>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7fdd858c13a0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1400>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1460>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x7fdd858c14c0>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1520>,
#  'disposable': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1580>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x7fdd858c15e0>,
#  'period': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1640>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x7fdd858c16a0>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1700>,
#  'forced': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1760>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7fdd858c17c0>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1820>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1880>,
#  'gps': <gensim.models.keyedvectors.Vocab at 0x7fdd858c18e0>,
#  'wallet': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1940>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x7fdd858c19a0>,
#  'minutes': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1a00>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1a60>,
#  'pulled': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1ac0>,
#  'smelled': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1b20>,
#  'burnt': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1b80>,
#  'careful': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1be0>,
#  'fire': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1c40>,
#  'hazard': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1ca0>,
#  'potentially': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1d00>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1d60>,
#  'electrical': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1dc0>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1e20>,
#  'portable': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1e80>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1ee0>,
#  'pair': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1f40>,
#  'extra': <gensim.models.keyedvectors.Vocab at 0x7fdd858c1fa0>,
#  'spare': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3040>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7fdd858c30a0>,
#  'quicker': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3100>,
#  'dying': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3160>,
#  'gs': <gensim.models.keyedvectors.Vocab at 0x7fdd858c31c0>,
#  'htc': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3220>,
#  'evo': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3280>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7fdd858c32e0>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3340>,
#  'retailers': <gensim.models.keyedvectors.Vocab at 0x7fdd858c33a0>,
#  'anonymous': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3400>,
#  'chinese': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3460>,
#  'factory': <gensim.models.keyedvectors.Vocab at 0x7fdd858c34c0>,
#  'alike': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3520>,
#  're': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3580>,
#  'deliver': <gensim.models.keyedvectors.Vocab at 0x7fdd858c35e0>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3640>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x7fdd858c36a0>,
#  'qc': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3700>,
#  'forever': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3760>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x7fdd858c37c0>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3820>,
#  'par': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3880>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x7fdd858c38e0>,
#  'die': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3940>,
#  'replacements': <gensim.models.keyedvectors.Vocab at 0x7fdd858c39a0>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3a00>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3a60>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3ac0>,
#  'indicates': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3b20>,
#  'plugged': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3b80>,
#  'correctly': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3be0>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3c40>,
#  'rental': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3ca0>,
#  'cars': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3d00>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3d60>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3dc0>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3e20>,
#  'totally': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3e80>,
#  'pleased': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3ee0>,
#  'clever': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3f40>,
#  'gems': <gensim.models.keyedvectors.Vocab at 0x7fdd858c3fa0>,
#  'complaints': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4040>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x7fdd858c40a0>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4100>,
#  'trails': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4160>,
#  'smaller': <gensim.models.keyedvectors.Vocab at 0x7fdd858c41c0>,
#  'shipping': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4220>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4280>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x7fdd858c42e0>,
#  'bright': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4340>,
#  'annoying': <gensim.models.keyedvectors.Vocab at 0x7fdd858c43a0>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4400>,
#  'feels': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4460>,
#  'rubber': <gensim.models.keyedvectors.Vocab at 0x7fdd858c44c0>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4520>,
#  'wears': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4580>,
#  'paint': <gensim.models.keyedvectors.Vocab at 0x7fdd858c45e0>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4640>,
#  'sealant': <gensim.models.keyedvectors.Vocab at 0x7fdd858c46a0>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4700>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4760>,
#  'rubbing': <gensim.models.keyedvectors.Vocab at 0x7fdd858c47c0>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4820>,
#  'worried': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4880>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x7fdd858c48e0>,
#  'description': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4940>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x7fdd858c49a0>,
#  'changing': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4a00>,
#  'desireable': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4a60>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4ac0>,
#  'orange': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4b20>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4b80>,
#  'alas': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4be0>,
#  'earlier': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4c40>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4ca0>,
#  'pink': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4d00>,
#  'rubberized': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4d60>,
#  'greasy': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4dc0>,
#  'armor': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4e20>,
#  'gorgeous': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4e80>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4ee0>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4f40>,
#  'silver': <gensim.models.keyedvectors.Vocab at 0x7fdd858c4fa0>,
#  'arrive': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6040>,
#  'defintiely': <gensim.models.keyedvectors.Vocab at 0x7fdd858c60a0>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6100>,
#  'cell': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6160>,
#  'stores': <gensim.models.keyedvectors.Vocab at 0x7fdd858c61c0>,
#  'mark': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6220>,
#  'quickly': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6280>,
#  'vivid': <gensim.models.keyedvectors.Vocab at 0x7fdd858c62e0>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6340>,
#  'durable': <gensim.models.keyedvectors.Vocab at 0x7fdd858c63a0>,
#  'wanting': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6400>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6460>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x7fdd858c64c0>,
#  'covers': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6520>,
#  'snazzy': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6580>,
#  'shortly': <gensim.models.keyedvectors.Vocab at 0x7fdd858c65e0>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6640>,
#  'peel': <gensim.models.keyedvectors.Vocab at 0x7fdd858c66a0>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6700>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6760>,
#  'missing': <gensim.models.keyedvectors.Vocab at 0x7fdd858c67c0>,
#  'spots': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6820>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6880>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x7fdd858c68e0>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6940>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x7fdd858c69a0>,
#  'isnt': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6a00>,
#  'protection': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6a60>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6ac0>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6b20>,
#  'install': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6b80>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6be0>,
#  'protect': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6c40>,
#  'liked': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6ca0>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6d00>,
#  'dose': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6d60>,
#  'scratches': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6dc0>,
#  'ive': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6e20>,
#  'didnt': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6e80>,
#  'break': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6ee0>,
#  'scratch': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6f40>,
#  'gotten': <gensim.models.keyedvectors.Vocab at 0x7fdd858c6fa0>,
#  'complements': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8040>,
#  'bucks': <gensim.models.keyedvectors.Vocab at 0x7fdd858c80a0>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8100>,
#  'afordable': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8160>,
#  'peels': <gensim.models.keyedvectors.Vocab at 0x7fdd858c81c0>,
#  'dollor': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8220>,
#  'mine': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8280>,
#  'electromaster': <gensim.models.keyedvectors.Vocab at 0x7fdd858c82e0>,
#  'snaps': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8340>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x7fdd858c83a0>,
#  'surely': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8400>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8460>,
#  'dollar': <gensim.models.keyedvectors.Vocab at 0x7fdd858c84c0>,
#  'hopes': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8520>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8580>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x7fdd858c85e0>,
# ...
#  'awhile': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8b20>,
#  'shoes': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8b80>,
#  'considering': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8be0>,
#  'purple': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8c40>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8ca0>,
#  'leopard': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8d00>,
#  'hopefully': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8d60>,
#  'trouble': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8dc0>,
#  'cutest': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8e20>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8e80>,
#  'apply': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8ee0>,
#  'uses': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8f40>,
#  'hem': <gensim.models.keyedvectors.Vocab at 0x7fdd858c8fa0>,
#  'sweater': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9040>,
#  'stretched': <gensim.models.keyedvectors.Vocab at 0x7fdd858c90a0>,
#  'intact': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9100>,
#  'woo': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9160>,
#  'hoo': <gensim.models.keyedvectors.Vocab at 0x7fdd858c91c0>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9220>,
#  'anymore': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9280>,
#  'judgement': <gensim.models.keyedvectors.Vocab at 0x7fdd858c92e0>,
#  'woks': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9340>,
#  'genuine': <gensim.models.keyedvectors.Vocab at 0x7fdd858c93a0>,
#  'blackberry': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9400>,
#  'incase': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9460>,
#  'forget': <gensim.models.keyedvectors.Vocab at 0x7fdd858c94c0>,
#  'honestly': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9520>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9580>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x7fdd858c95e0>,
#  'worrying': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9640>,
#  'losing': <gensim.models.keyedvectors.Vocab at 0x7fdd858c96a0>,
#  'leaving': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9700>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9760>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x7fdd858c97c0>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9820>,
#  'patient': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9880>,
#  'folding': <gensim.models.keyedvectors.Vocab at 0x7fdd858c98e0>,
#  'blades': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9940>,
#  'models': <gensim.models.keyedvectors.Vocab at 0x7fdd858c99a0>,
#  'adapters': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9a00>,
#  'countries': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9a60>,
#  'specified': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9ac0>,
#  'jus': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9b20>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9b80>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9be0>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9c40>,
#  'portal': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9ca0>,
#  'judy': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9d00>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9d60>,
#  'slower': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9dc0>,
#  'goes': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9e20>,
#  'tends': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9e80>,
#  'firmly': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9ee0>,
#  'affordable': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9f40>,
#  'afford': <gensim.models.keyedvectors.Vocab at 0x7fdd858c9fa0>,
#  'lives': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb040>,
#  'luggage': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb0a0>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb100>,
#  'spend': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb160>,
#  'convenience': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb1c0>,
#  'crappy': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb220>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb280>,
#  'tall': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb2e0>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb340>,
#  'struggle': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb3a0>,
#  'laying': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb400>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb460>,
#  'blocky': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb4c0>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb520>,
#  'connecter': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb580>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb5e0>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb640>,
#  'wiggle': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb6a0>,
#  'disconnects': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb700>,
#  'worn': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb760>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb7c0>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb820>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb880>,
#  'failed': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb8e0>,
#  'cable': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb940>,
#  'tons': <gensim.models.keyedvectors.Vocab at 0x7fdd858cb9a0>,
#  'ad': <gensim.models.keyedvectors.Vocab at 0x7fdd858cba00>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x7fdd858cba60>,
#  'thru': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbac0>,
#  'wasn': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbb20>,
#  'expecting': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbb80>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbbe0>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbc40>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbca0>,
#  'kinda': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbd00>,
#  'purchasing': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbd60>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbdc0>,
#  'figured': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbe20>,
#  'heck': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbe80>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbee0>,
#  'decided': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbf40>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x7fdd858cbfa0>,
#  'timed': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd040>,
#  'mention': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd0a0>,
#  'reviewer': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd100>,
#  'meant': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd160>,
#  'saying': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd1c0>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd220>,
#  'backup': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd280>,
#  'sgs': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd2e0>,
#  'wonderfully': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd340>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd3a0>,
#  'recommended': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd400>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd460>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd4c0>,
#  'rough': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd520>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd580>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd5e0>,
#  'passenger': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd640>,
#  'seat': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd6a0>,
#  'comfortably': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd700>,
#  'coiled': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd760>,
#  'section': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd7c0>,
#  'stress': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd820>,
#  'realize': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd880>,
#  'eventually': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd8e0>,
#  'girlfriend': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd940>,
#  'oem': <gensim.models.keyedvectors.Vocab at 0x7fdd858cd9a0>,
#  'fanboy': <gensim.models.keyedvectors.Vocab at 0x7fdd858cda00>,
#  'swooped': <gensim.models.keyedvectors.Vocab at 0x7fdd858cda60>,
#  'remaining': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdac0>,
#  'slightly': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdb20>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdb80>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdbe0>,
#  'sealed': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdc40>,
#  'bags': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdca0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdd00>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdd60>,
#  'normally': <gensim.models.keyedvectors.Vocab at 0x7fdd858cddc0>,
#  'receive': <gensim.models.keyedvectors.Vocab at 0x7fdd858cde20>,
#  'refurb': <gensim.models.keyedvectors.Vocab at 0x7fdd858cde80>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdee0>,
#  'certainly': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdf40>,
#  'argue': <gensim.models.keyedvectors.Vocab at 0x7fdd858cdfa0>,
#  'benefits': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce040>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce0a0>,
#  'generic': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce100>,
#  'reliability': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce160>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce1c0>,
#  'solidly': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce220>,
#  'verizon': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce280>,
#  'lame': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce2e0>,
#  'issues': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce340>,
#  'retractable': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce3a0>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce400>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce460>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce4c0>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce520>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce580>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce5e0>,
#  'junk': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce640>,
#  'amazon': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce6a0>,
#  'fraction': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce700>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce760>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce7c0>,
#  'cords': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce820>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce880>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce8e0>,
#  'verses': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce940>,
#  'chargingi': <gensim.models.keyedvectors.Vocab at 0x7fdd858ce9a0>,
#  'persons': <gensim.models.keyedvectors.Vocab at 0x7fdd858cea00>,
#  'mo': <gensim.models.keyedvectors.Vocab at 0x7fdd858cea60>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x7fdd858ceac0>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x7fdd858ceb20>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x7fdd858ceb80>,
#  'labeled': <gensim.models.keyedvectors.Vocab at 0x7fdd858cebe0>,
#  'lights': <gensim.models.keyedvectors.Vocab at 0x7fdd858cec40>,
#  'happens': <gensim.models.keyedvectors.Vocab at 0x7fdd858ceca0>,
#  'defective': <gensim.models.keyedvectors.Vocab at 0x7fdd858ced00>,
#  'upsetting': <gensim.models.keyedvectors.Vocab at 0x7fdd858ced60>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x7fdd858cedc0>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7fdd858cee20>,
#  'reliable': <gensim.models.keyedvectors.Vocab at 0x7fdd858cee80>,
#  'motorola': <gensim.models.keyedvectors.Vocab at 0x7fdd858ceee0>,
#  'dependable': <gensim.models.keyedvectors.Vocab at 0x7fdd858cef40>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7fdd858cefa0>,
#  'fuse': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0040>,
#  'blown': <gensim.models.keyedvectors.Vocab at 0x7fdd858d00a0>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0100>,
#  'attempted': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0160>,
#  'noticed': <gensim.models.keyedvectors.Vocab at 0x7fdd858d01c0>,
#  'apart': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0220>,
#  'upload': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0280>,
#  'sum': <gensim.models.keyedvectors.Vocab at 0x7fdd858d02e0>,
#  'juice': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0340>,
#  'dropping': <gensim.models.keyedvectors.Vocab at 0x7fdd858d03a0>,
#  'repeatedly': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0400>,
#  'floorboard': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0460>,
#  'occasionally': <gensim.models.keyedvectors.Vocab at 0x7fdd858d04c0>,
#  'stuffing': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0520>,
#  'hide': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0580>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x7fdd858d05e0>,
#  'failure': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0640>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7fdd858d06a0>,
#  'display': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0700>,
#  'dollars': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0760>,
#  'witha': <gensim.models.keyedvectors.Vocab at 0x7fdd858d07c0>,
#  'heavier': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0820>,
#  'shell': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0880>,
#  'treat': <gensim.models.keyedvectors.Vocab at 0x7fdd858d08e0>,
#  'delicate': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0940>,
#  'flower': <gensim.models.keyedvectors.Vocab at 0x7fdd858d09a0>,
#  'sprint': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0a00>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0a60>,
#  'fro': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0ac0>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0b20>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0b80>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0be0>,
#  'hasn': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0c40>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0ca0>,
#  'bargain': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0d00>,
#  'expert': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0d60>,
#  'fireworks': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0dc0>,
#  'hotel': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0e20>,
#  'parties': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0e80>,
#  'nexus': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0ee0>,
#  'microusb': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0f40>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7fdd858d0fa0>,
#  'originally': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2040>,
#  'prefectly': <gensim.models.keyedvectors.Vocab at 0x7fdd858d20a0>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2100>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2160>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x7fdd858d21c0>,
#  'official': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2220>,
#  'straight': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2280>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x7fdd858d22e0>,
#  'flimsy': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2340>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x7fdd858d23a0>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2400>,
#  'functioned': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2460>,
#  'window': <gensim.models.keyedvectors.Vocab at 0x7fdd858d24c0>,
#  'guessing': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2520>,
#  'knows': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2580>,
#  'es': <gensim.models.keyedvectors.Vocab at 0x7fdd858d25e0>,
#  'un': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2640>,
#  'para': <gensim.models.keyedvectors.Vocab at 0x7fdd858d26a0>,
#  'carro': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2700>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2760>,
#  'excelente': <gensim.models.keyedvectors.Vocab at 0x7fdd858d27c0>,
#  'calidad': <gensim.models.keyedvectors.Vocab at 0x7fdd858d2820>,
#  ...}

# %%
vocab['sum'].index
# Out:
# 4697

# %%
vocab_int2word = {c.index:w for w,c in vocab.items()}

# %%
vocab_int2word
# Out:
# {39: 'they',
#  153: 'look',
#  37: 'good',
#  2: 'and',
#  606: 'stick',
#  36: 'just',
#  73: 'don',
#  25: 'like',
#  0: 'the',
#  2038: 'rounded',
#  1026: 'shape',
#  71: 'because',
#  19: 'was',
#  238: 'always',
#  5098: 'bumping',
#  1: 'it',
#  2061: 'siri',
#  784: 'kept',
#  2811: 'popping',
#  52: 'up',
#  3494: 'irritating',
#  308: 'won',
#  120: 'buy',
#  60: 'product',
#  5: 'this',
#  190: 'again',
#  67: 'these',
#  1900: 'stickers',
#  87: 'work',
#  194: 'review',
#  612: 'says',
#  72: 'do',
#  11: 'on',
#  30: 'great',
#  493: 'stay',
#  12: 'phone',
#  24: 'are',
#  407: 'super',
#  970: 'stylish',
#  28: 'can',
#  1759: 'share',
#  74: 'them',
#  13: 'with',
#  8: 'my',
#  1660: 'sister',
#  376: 'awesome',
#  141: 'make',
#  21: 'so',
#  17: 'have',
#  57: 'only',
#  97: 'used',
#  22: 'one',
#  178: 'far',
#  49: 'had',
#  7: 'for',
#  291: 'almost',
#  411: 'year',
#  14: 'you',
#  717: 'believe',
#  9: 'that',
#  85: 'quality',
#  247: 'item',
#  488: 'arrived',
#  10: 'in',
#  64: 'time',
#  151: 'perfect',
#  1352: 'condition',
#  175: 'however',
#  285: 'ordered',
#  201: 'buttons',
#  168: 'were',
#  370: 'deal',
#  382: 'included',
#  317: 'free',
#  35: 'screen',
#  98: 'protector',
#  207: 'never',
#  269: 'received',
#  185: 'though',
#  83: 'its',
#  18: 'not',
#  230: 'big',
#  42: 'would',
#  92: 've',
#  132: 'been',
#  78: 'nice',
#  3: 'to',
#  50: 'get',
#  159: 'since',
#  1796: 'claim',
#  187: 'comes',
#  770: 'stays',
#  119: 'looks',
#  27: 'be',
#  636: 'multiple',
#  226: 'apple',
#  373: 'products',
#  396: 'especially',
#  220: 'having',
#  2851: 'nails',
#  833: 'helps',
#  46: 'an',
#  6185: 'elevated',
#  1125: 'key',
#  101: 'using',
#  313: 'home',
#  162: 'button',
#  90: 'easy',
#  707: 'daughter',
#  163: 'both',
#  282: 'purchase',
#  45: 'well',
#  256: 'worth',
#  80: 'price',
#  177: 'came',
#  20: 'as',
#  841: 'described',
#  115: 'doesn',
#  242: 'come',
#  9488: 'unstuck',
#  400: 'cute',
#  248: 'people',
#  1030: 'ask',
#  206: 'where',
#  102: 'got',
#  41: 'from',
#  33: 'when',
#  752: 'driving',
#  258: 'worked',
#  110: 'first',
#  442: 'week',
#  116: 'then',
#  51: 'charge',
#  4: 'is',
#  952: 'waste',
#  6: 'of',
#  284: 'money',
#  15: 'case',
#  410: 'solid',
#  761: 'build',
#  381: 'protects',
#  38: 'all',
#  131: 'around',
#  550: 'access',
#  40: 'battery',
#  263: 'charges',
#  268: 'full',
#  934: 'lasts',
#  54: 'me',
#  170: 'day',
#  613: 'usually',
#  569: 'leave',
#  737: 'house',
#  104: 'am',
#  682: 'return',
#  32: 'at',
#  1969: 'pm',
#  746: 'glad',
#  615: 'start',
#  276: 'end',
#  906: 'fantastic',
#  23: 'very',
#  468: 'features',
#  124: 'without',
#  89: 'any',
#  1917: 'loss',
#  1169: 'reception',
#  16: 'but',
#  156: 'most',
#  2384: 'importantly',
#  1086: 'double',
#  100: 'power',
#  1509: 'promised',
#  114: 'fits',
#  180: 'perfectly',
#  583: 'keeps',
#  27228: 'powerd',
#  1096: 'complain',
#  111: 'recommend',
#  133: 'galaxy',
#  359: 'slim',
#  412: 'add',
#  75: 'much',
#  464: 'weight',
#  2371: 'doubles',
#  227: 'life',
#  341: 'either',
#  29: 'or',
#  62: 'there',
#  536: 'handy',
#  66: 'off',
#  522: 'switch',
#  1701: 'leds',
#  1668: 'indicate',
#  727: 'level',
#  1453: 'packaged',
#  2024: 'performs',
#  363: 'exactly',
#  758: 'advertised',
#  8802: 'sturdily',
#  364: 'built',
#  501: 'provides',
#  1010: 'lots',
#  1682: 'boost',
#  70: 'does',
#  77: 'what',
#  789: 'supposed',
#  94: 'too',
#  1274: 'insert',
#  43: 'out',
#  262: 'definitely',
#  461: 'star',
#  574: 'experience',
#  189: 'know',
#  81: 'love',
#  860: 'unlike',
#  2045: 'rechargeable',
#  128: 'cases',
#  14402: 'powerbear',
#  642: 'whole',
#  257: 'days',
#  1521: 'heat',
#  61: 'other',
#  388: 'ones',
#  465: 'completely',
#  11073: 'fascinated',
#  108: 'by',
#  1329: 'ultra',
#  195: 'light',
#  691: 'sleek',
#  216: 'design',
#  186: 'before',
#  1522: 'mophie',
#  588: 'couldn',
#  505: 'wear',
#  546: 'often',
#  919: 'hot',
#  2003: 'brick',
#  31: 'your',
#  222: 'pocket',
#  2542: 'hence',
#  4987: 'contrary',
#  160: 'take',
#  91: 'even',
#  406: 'tell',
#  701: 'difference',
#  65: 'also',
#  631: 'strong',
#  2453: 'manner',
#  315: 'dropped',
#  148: 'few',
#  214: 'times',
#  1419: 'shock',
#  1261: 'resistant',
#  1117: 'technology',
#  425: 'let',
#  751: 'single',
#  137: 'thing',
#  1185: 'happen',
#  1854: 'became',
#  1979: 'extension',
#  632: 'night',
#  56: 'more',
#  55: 'than',
#  106: 'two',
#  3307: 'shocked',
#  408: 'hear',
#  1374: 'positive',
#  1020: 'compliments',
#  1416: 'hearing',
#  321: 'job',
#  5302: 'fitness',
#  1247: 'center',
#  2113: 'throughout',
#  5605: 'community',
#  3065: 'everybody',
#  2622: 'loving',
#  497: 'cost',
#  729: 'cheaper',
#  478: 'brand',
#  155: 'best',
#  154: 'made',
#  1041: 'internet',
#  217: 'going',
#  819: 'family',
#  5277: 'holidays',
#  792: 'thank',
#  314: 'needed',
#  645: 'myself',
#  3806: 'sons',
#  127: 'new',
#  419: 'replacement',
#  288: 'batteries',
#  107: 'now',
#  296: 'isn',
#  655: 'thanks',
#  53: 'no',
#  1353: 'outlets',
#  349: 'chargers',
#  817: 'near',
#  7227: 'rescue',
#  779: 'husband',
#  69: 'works',
#  1542: 'crazy',
#  5783: 'definetly',
#  1410: 'thats',
#  345: 'why',
#  358: 'wife',
#  1927: 'wonder',
#  1067: 'called',
#  3166: 'bear',
#  1650: 'surprisingly',
#  903: 'inexpensive',
#  492: 'version',
#  3290: 'reliably',
#  479: 'expensive',
#  1427: 'variety',
#  47: 'has',
#  366: 'working',
#  281: 'months',
#  176: 'problem',
#  305: 'excellent',
#  649: 'value',
#  680: 'tested',
#  675: 'against',
#  2704: 'griffin',
#  619: 'dual',
#  608: 'output',
#  211: 'unit',
#  2100: 'checked',
#  86: 'charging',
#  774: 'current',
#  182: 'note',
#  1324: 'ma',
#  144: 'long',
#  105: 'bought',
#  213: 'cheap',
#  225: 'actually',
#  413: 'seem',
#  560: 'provide',
#  300: 'high',
#  659: 'idea',
#  125: 'how',
#  231: 'last',
#  2105: 'assume',
#  44: 'will',
#  203: 'fine',
#  121: 'did',
#  1158: 'testing',
#  787: 'stock',
#  58: 'charger',
#  2844: 'passed',
#  11616: 'stocked',
#  322: 'couple',
#  405: 'weeks',
#  1000: 'stopped',
#  1004: 'basically',
#  165: 'small',
#  295: 'ports',
#  372: 'ipod',
#  240: 'who',
#  1242: 'wants',
#  660: 'putting',
#  193: 'many',
#  304: 'things',
#  1230: 'socket',
#  714: 'convenient',
#  496: 'store',
#  113: 'need',
#  198: 'find',
#  169: 'another',
#  1066: 'amps',
#  1429: 'ipads',
#  3136: 'hp',
#  15733: 'touchpads',
#  708: 'compact',
#  386: 'nothing',
#  1362: 'special',
#  197: 'sure',
#  1284: 'powered',
#  445: 'led',
#  3879: 'glows',
#  212: 'able',
#  150: 'phones',
#  218: 'once',
#  122: 'car',
#  68: 'which',
#  293: 'several',
#  1336: 'vehicle',
#  171: 'keep',
#  424: 'each',
#  1970: 'frustrating',
#  1537: 'finding',
#  4271: 'sudden',
#  9827: 'quits',
#  129: 'way',
#  705: 'recharge',
#  79: 'little',
#  1901: 'skeptical',
#  95: 'after',
#  228: 'tried',
#  927: 'lasted',
#  59: 'about',
#  26: 'if',
#  1684: 'changes',
#  332: 'update',
#  626: 'disappointed',
#  166: 'didn',
#  188: 'ipad',
#  432: 'buying',
#  343: 'adapter',
#  1664: 'cheaply',
#  1518: 'china',
#  836: 'radio',
#  414: 'gets',
#  1512: 'static',
#  1013: 'stop',
#  1798: 'lines',
#  1322: 'station',
#  297: 'away',
#  6899: 'rf',
#  8918: 'shielding',
#  485: 'gave',
#  278: 'stars',
#  764: 'listen',
#  334: 'might',
#  1017: 'consider',
#  210: 'side',
#  5179: 'yo',
#  355: 'order',
#  2657: 'timely',
#  2407: 'fashion',
#  3395: 'terribly',
#  7158: 'subaru',
#  2192: 'console',
#  6276: 'passengers',
#  7311: 'emits',
#  319: 'blue',
#  2869: 'glow',
#  862: 'held',
#  2075: 'abuse',
#  117: 'over',
#  462: 'years',
#  6848: 'bough',
#  205: 'different',
#  490: 'wouldn',
#  607: 'jack',
#  245: 'give',
#  572: 'connect',
#  357: 'cables',
#  8692: 'overheated',
#  5466: 'burning',
#  8693: 'fuses',
#  224: 'purchased',
#  136: 'same',
#  272: 'bad',
#  724: 'dont',
#  883: 'wait',
#  618: 'finish',
#  289: 'her',
#  167: 'looking',
#  2273: 'waited',
#  330: 'piece',
#  152: 'plastic',
#  1773: 'crap',
#  1805: 'shouldn',
#  394: 'expected',
#  2217: 'handling',
#  4668: 'announced',
#  3121: 'reached',
#  1636: 'shown',
#  331: 'everything',
#  191: 'we',
#  123: 'put',
#  401: 'our',
#  653: 'together',
#  34: 'use',
#  82: 'usb',
#  142: 'devices',
#  174: 'think',
#  20759: 'counseling',
#  452: 'haven',
#  318: 'problems',
#  5817: 'yrs',
#  466: 'month',
#  733: 'ago',
#  518: 'pros',
#  540: 'loved',
#  484: 'cool',
#  377: 'feature',
#  200: 'plug',
#  112: 'into',
#  914: 'lighter',
#  1333: 'con',
#  243: 'top',
#  208: 'clear',
#  173: 'easily',
#  6634: 'overtime',
#  942: 'tape',
#  1097: 'total',
#  657: 'cons',
#  135: 'could',
#  987: 'tab',
#  2530: 'recognize',
#  183: 'port',
#  99: 'while',
#  48: 'iphone',
#  344: 'tablet',
#  2457: 'stronger',
#  96: 'still',
#  253: 'touch',
#  143: 'samsung',
#  598: 'outlet',
#  395: 'low',
#  1154: 'profile',
#  762: 'tablets',
#  1044: 'smartphones',
#  138: 'bluetooth',
#  650: 'speakers',
#  611: 'headsets',
#  371: 'anyone',
#  1259: 'universal',
#  409: 'although',
#  7083: 'subsequently',
#  1643: 'died',
#  280: 'bottom',
#  796: 'slot',
#  981: 'lower',
#  5851: 'presumably',
#  453: 'holds',
#  514: 'tight',
#  84: 'some',
#  628: 'loose',
#  292: 'android',
#  811: 'except',
#  1008: 'ready',
#  3500: 'sockets',
#  1657: 'tightly',
#  88: 'fit',
#  145: 'pretty',
#  1114: 'construction',
#  266: 'less',
#  63: 'really',
#  2471: 'enjoyed',
#  3417: 'rapidly',
#  221: 'charged',
#  662: 'friends',
#  184: 'makes',
#  519: 'else',
#  192: 'their',
#  93: 'device',
#  684: 'unless',
#  352: 'remove',
#  254: 'cord',
#  730: 'course',
#  134: 'go',
#  76: 'back',
#  1975: 'began',
#  795: 'notice',
#  9179: 'flickering',
#  732: 'later',
#  2658: 'quit',
#  2862: 'permanently',
#  3396: 'faulty',
#  4533: 'wiring',
#  570: 'guess',
#  244: 'll',
#  316: 'thought',
#  249: 'getting',
#  103: 'better',
#  440: 'maybe',
#  526: 'simply',
#  4742: 'disposable',
#  421: 'short',
#  1461: 'period',
#  992: 'whatever',
#  431: 'reason',
#  3159: 'forced',
#  251: 'found',
#  576: 'range',
#  310: 'yet',
#  547: 'gps',
#  810: 'wallet',
#  527: 'test',
#  457: 'minutes',
#  846: 'felt',
#  1634: 'pulled',
#  6744: 'smelled',
#  6241: 'burnt',
#  828: 'careful',
#  959: 'fire',
#  6435: 'hazard',
#  3548: 'potentially',
#  4619: 'destroy',
#  1976: 'electrical',
#  743: 'system',
#  543: 'portable',
#  447: 'must',
#  575: 'pair',
#  283: 'extra',
#  851: 'spare',
#  202: 'seems',
#  2301: 'quicker',
#  2441: 'dying',
#  780: 'gs',
#  369: 'htc',
#  741: 'evo',
#  204: 'something',
#  1081: 'various',
#  5897: 'retailers',
#  15734: 'anonymous',
#  2742: 'chinese',
#  1514: 'factory',
#  5898: 'alike',
#  199: 're',
#  2261: 'deliver',
#  196: 'say',
#  520: 'expect',
#  7312: 'qc',
#  1397: 'forever',
#  1464: 'active',
#  982: 'daily',
#  2135: 'par',
#  3149: 'suddenly',
#  1930: 'die',
#  2502: 'replacements',
#  311: 'hand',
#  617: 'yes',
#  265: 'every',
#  2389: 'indicates',
#  402: 'plugged',
#  1106: 'correctly',
#  1203: 'helpful',
#  3772: 'rental',
#  1568: 'cars',
#  557: 'travel',
#  999: 'behind',
#  2156: 'hey',
#  907: 'totally',
#  566: 'pleased',
#  3246: 'clever',
#  4192: 'gems',
#  721: 'complaints',
#  786: 'hope',
#  241: 'happy',
#  6635: 'trails',
#  623: 'smaller',
#  504: 'shipping',
#  306: 'took',
#  338: 'longer',
#  581: 'bright',
#  712: 'annoying',
#  235: 'overall',
#  267: 'feels',
#  250: 'rubber',
#  2174: 'sweet',
#  2626: 'wears',
#  2203: 'paint',
#  458: 'under',
#  18994: 'sealant',
#  335: 'anything',
#  1350: 'effect',
#  2815: 'rubbing',
#  275: 'quite',
#  1208: 'worried',
#  480: 'picture',
#  1005: 'description',
#  1552: 'page',
#  1760: 'changing',
#  20760: 'desireable',
#  844: 'green',
#  1402: 'orange',
#  118: 'cover',
#  4520: 'alas',
#  1498: 'earlier',
#  765: 'beautiful',
#  627: 'pink',
#  1115: 'rubberized',
#  3862: 'greasy',
#  946: 'armor',
#  2204: 'gorgeous',
#  469: 'change',
#  307: 'white',
#  1341: 'silver',
#  1735: 'arrive',
#  16582: 'defintiely',
#  209: 'should',
#  294: 'cell',
#  1563: 'stores',
#  2214: 'mark',
#  333: 'quickly',
#  3583: 'vivid',
#  422: 'soft',
#  433: 'durable',
#  2014: 'wanting',
#  337: 'old',
#  158: 'feel',
#  428: 'covers',
#  7313: 'snazzy',
#  3122: 'shortly',
#  549: 'started',
#  1076: 'peel',
#  418: 'until',
#  634: 'looked',
#  1437: 'missing',
#  2263: 'spots',
#  481: 'sometimes',
#  179: 'color',
#  1058: 'dark',
#  639: 'person',
#  2536: 'isnt',
#  126: 'protection',
#  172: 'lot',
#  380: 'simple',
#  415: 'install',
#  565: 'help',
#  259: 'protect',
#  534: 'liked',
#  966: 'ability',
#  4815: 'dose',
#  470: 'scratches',
#  1752: 'ive',
#  1273: 'didnt',
#  599: 'break',
#  587: 'scratch',
#  991: 'gotten',
#  3570: 'complements',
#  1012: 'bucks',
#  1345: 'spent',
#  18995: 'afordable',
#  4435: 'peels',
#  27229: 'dollor',
#  434: 'mine',
#  12241: 'electromaster',
#  1296: 'snaps',
#  347: 'drop',
#  3454: 'surely',
#  506: 'done',
#  1728: 'dollar',
#  2889: 'hopes',
#  637: 'show',
#  140: 'want',
#  515: 'protected',
#  3948: 'mile',
#  4793: 'outter',
#  340: 'box',
#  747: 'favorite',
#  896: 'broken',
#  1334: 'horrible',
#  1794: 'peeling',
#  350: 'left',
#  7389: 'orginal',
#  866: 'skin',
#  215: 'being',
#  1499: 'specific',
#  1716: 'awhile',
#  6488: 'shoes',
#  877: 'considering',
#  1104: 'purple',
#  255: 'black',
#  4816: 'leopard',
#  1420: 'hopefully',
#  921: 'trouble',
#  5351: 'cutest',
#  312: 'ever',
#  584: 'apply',
#  590: 'uses',
#  18996: 'hem',
#  8595: 'sweater',
#  2395: 'stretched',
#  3099: 'intact',
#  11912: 'woo',
#  11913: 'hoo',
#  161: 'see',
#  1152: 'anymore',
#  9331: 'judgement',
#  10633: 'woks',
#  1943: 'genuine',
#  624: 'blackberry',
#  3349: 'incase',
#  1045: 'forget',
#  1219: 'honestly',
#  622: 'model',
#  917: 'road',
#  2782: 'worrying',
#  1662: 'losing',
#  1285: 'leaving',
#  2673: 'meet',
#  274: 'fast',
#  463: 'needs',
#  3511: 'patient',
#  2537: 'folding',
#  6489: 'blades',
#  1253: 'models',
#  1060: 'adapters',
#  4937: 'countries',
#  4916: 'specified',
#  6968: 'jus',
#  1555: 'direct',
#  346: 'wall',
#  157: 'right',
#  10012: 'portal',
#  23267: 'judy',
#  149: 'bit',
#  1814: 'slower',
#  495: 'goes',
#  1823: 'tends',
#  1706: 'firmly',
#  1527: 'affordable',
#  2855: 'afford',
#  2998: 'lives',
#  5228: 'luggage',
#  524: 'quick',
#  909: 'spend',
#  1604: 'convenience',
#  2575: 'crappy',
#  775: 'length',
#  3231: 'tall',
#  1483: 'bed',
#  3058: 'struggle',
#  2055: 'laying',
#  164: 'down',
#  10844: 'blocky',
#  735: 'worry',
#  6969: 'connecter',
#  270: 'place',
#  521: 'fall',
#  2783: 'wiggle',
#  3807: 'disconnects',
#  1732: 'worn',
#  279: 'issue',
#  738: 'turned',
#  878: 'main',
#  1556: 'failed',
#  109: 'cable',
#  2175: 'tons',
#  3179: 'ad',
#  535: 'making',
#  2124: 'thru',
#  443: 'wasn',
#  1164: 'expecting',
#  404: 'between',
#  392: 'plus',
#  367: 'second',
#  1315: 'kinda',
#  1069: 'purchasing',
#  1043: 'mean',
#  1178: 'figured',
#  2484: 'heck',
#  848: 'today',
#  562: 'decided',
#  298: 'try',
#  6186: 'timed',
#  1196: 'mention',
#  1986: 'reviewer',
#  1489: 'meant',
#  1122: 'saying',
#  868: 'poor',
#  847: 'backup',
#  3418: 'sgs',
#  2422: 'wonderfully',
#  303: 'highly',
#  571: 'recommended',
#  309: 'here',
#  1035: 'future',
#  1351: 'rough',
#  375: 'wish',
#  1231: 'reach',
#  3408: 'passenger',
#  1825: 'seat',
#  1565: 'comfortably',
#  2788: 'coiled',
#  1994: 'section',
#  2824: 'stress',
#  1306: 'realize',
#  1135: 'eventually',
#  1860: 'girlfriend',
#  529: 'oem',
#  9332: 'fanboy',
#  27230: 'swooped',
#  1477: 'remaining',
#  456: 'slightly',
#  1075: 'mail',
#  2089: 'report',
#  2362: 'sealed',
#  4010: 'bags',
#  277: 'part',
#  444: 'kind',
#  1292: 'normally',
#  1014: 'receive',
#  7084: 'refurb',
#  523: 'wrong',
#  941: 'certainly',
#  4964: 'argue',
#  3092: 'benefits',
#  1519: 'vs',
#  1525: 'generic',
#  3440: 'reliability',
#  1423: 'list',
#  2269: 'solidly',
#  573: 'verizon',
#  4865: 'lame',
#  326: 'issues',
#  1736: 'retractable',
#  1290: 'thus',
#  1179: 'limited',
#  1906: 'fail',
#  2728: 'town',
#  929: 'name',
#  399: 'carry',
#  1534: 'junk',
#  236: 'amazon',
#  2596: 'fraction',
#  494: 'pay',
#  10013: 'national',
#  801: 'cords',
#  600: 'finally',
#  1749: 'local',
#  11617: 'verses',
#  23268: 'chargingi',
#  7466: 'persons',
#  5199: 'mo',
#  1082: 'cant',
#  857: 'beat',
#  1547: 'miss',
#  1776: 'labeled',
#  683: 'lights',
#  1452: 'happens',
#  1367: 'defective',
#  9654: 'upsetting',
#  1139: 'sit',
#  229: 'hours',
#  1335: 'reliable',
#  439: 'motorola',
#  4389: 'dependable',
#  597: 'within',
#  4011: 'fuse',
#  3485: 'blown',
#  390: 'inside',
#  3426: 'attempted',
#  672: 'noticed',
#  736: 'apart',
#  3392: 'upload',
#  4697: 'sum',
#  763: 'juice',
#  1022: 'dropping',
#  3773: 'repeatedly',
#  18997: 'floorboard',
#  1836: 'occasionally',
#  9489: 'stuffing',
#  2958: 'hide',
#  1769: 'caused',
#  3160: 'failure',
#  754: 'soon',
#  658: 'display',
#  1238: 'dollars',
#  12990: 'witha',
#  1541: 'heavier',
#  679: 'shell',
#  3495: 'treat',
#  3232: 'delicate',
#  5438: 'flower',
#  974: 'sprint',
#  320: 'wanted',
#  7314: 'fro',
#  1037: 'third',
#  1331: 'party',
#  728: 'market',
#  1256: 'hasn',
#  368: 'fact',
#  2095: 'bargain',
#  4390: 'expert',
#  17645: 'fireworks',
#  2413: 'hotel',
#  5130: 'parties',
#  323: 'nexus',
#  1471: 'microusb',
#  336: 'three',
#  1492: 'originally',
#  11914: 'prefectly',
#  234: 'hold',
#  1227: 'certain',
#  441: 'instead',
#  2125: 'official',
#  1116: 'straight',
#  652: 'talk',
#  876: 'flimsy',
#  953: 'feeling',
#  648: 'past',
#  5079: 'functioned',
#  1176: 'window',
#  2899: 'guessing',
#  2042: 'knows',
#  4110: 'es',
#  2959: 'un',
#  5504: 'para',
#  16583: 'carro',
#  2960: 'de',
#  8378: 'excelente',
#  9828: 'calidad',
#  ...}

# %%
vocab_int2word[4697]
# Out:
# 'sum'

# %%
import numpy as np
one_hot = np.zeros(shape=(1,vocab_len))

one_hot[0,vocab['awesome'].index] = 1

# %%
z_proj = np.dot(one_hot,matrix)
z_proj.shape
# Out:
# (1, 100)

# %%
a_proj = z_proj

z_out = np.dot(a_proj,W_out.T)
z_out.shape
# Out:
# (1, 35561)

# %%
#Softmax
a_out = np.exp(z_out)/np.sum(np.exp(z_out))

# %%
a_out.shape
# Out:
# (1, 35561)

# %%
a_out = a_out.flatten()

indices = np.argsort(a_out) #sort in ascending order
indices = indices[::-1] # sort in descending order

for i in range(10):
  word_index = indices[i]
  word = vocab_int2word[word_index]
  a_out_i = a_out[word_index]

  print(f"{word} with score {a_out_i}")
# Out:
# an with score 0.48372983892976995
# absolutely with score 0.029935524278960006
# looks with score 0.014451381401629673
# sounds with score 0.004642831972094724
# super with score 0.0030537353331718487
# thank with score 0.0024008964369231704
# value with score 0.0022518692033125735
# wow with score 0.0018033326267052863
# price with score 0.0016690454157502115
# service with score 0.0016453545344619445
